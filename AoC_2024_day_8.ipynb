# %% [markdown]
# <a href="https://colab.research.google.com/github/yufengg/advent-of-code-2024/blob/master/AoC_2024_day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: python code download advent of code file

import requests
import os
from datetime import datetime

def download_aoc_input(year, day, session_cookie):
  """Downloads the input file for a specific Advent of Code day.

  Args:
    year: The year of the challenge (e.g., 2023).
    day: The day of the challenge (e.g., 1).
    session_cookie: Your session cookie from the Advent of Code website.
  """

  url = f"https://adventofcode.com/{year}/day/{day}/input"
  headers = {
      "User-Agent": "github.com/yourusername/yourrepo (or your email)",  # Replace with your info
      "Cookie": f"session={session_cookie}"
  }

  try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an exception for bad status codes

    # Create a directory for the year if it doesn't exist
    os.makedirs(str(year), exist_ok=True)

    filename = os.path.join(str(year), f"day{day}.txt")
    with open(filename, "w") as file:
      file.write(response.text)
    print(f"Successfully downloaded input for year {year}, day {day} to {filename}")
    return filename

  except requests.exceptions.RequestException as e:
    print(f"Error downloading input: {e}")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")


# Example usage:  Replace with your actual values
year = 2024  #@param {type:"integer"}
day = 8 #@param {type:"integer"}
session_cookie = "53616c7465645f5fd6809f86933785dcec3c4f79b521758a796b0808898e32ff9a09d06dd15282b2a68340b7bf970ab66894fa0bf9271caa521bc5d5fc8df3b9" #@param {type:"string"}

input_filename = download_aoc_input(year, day, session_cookie)
# Out:
# Successfully downloaded input for year 2024, day 8 to 2024/day8.txt

# %%
import jax
import jax.numpy as jnp
import numpy as np

# %%
def read_input(filename, parser=None):
  with open(filename, 'r') as file:
    lines = file.read().splitlines()
    if parser:
      lines = list(map(parser, lines))
  return lines

# %%
input_filename = f'{year}/day{day}.txt'
def parser(line):

  return line

input_lines = read_input(input_filename, parser)

# %%
input_lines[0:5]
# Out:
# ['...d............................J.................',
#  '......e.............................J.............',
#  '..........6............7..........................',
#  '........................P7........................',
#  '..................................................']

# %% [markdown]
# # TEST data

# %%
test_data = """............
........0...
.....0......
.......0....
....0.......
......A.....
............
............
........A...
.........A..
............
............
"""

test_filename = f'{year}/test.txt'

with open(test_filename, 'w') as file:
  file.write(test_data)

# %%
test_lines = read_input(test_filename, parser)

# %%
test_lines
# Out:
# ['............',
#  '........0...',
#  '.....0......',
#  '.......0....',
#  '....0.......',
#  '......A.....',
#  '............',
#  '............',
#  '........A...',
#  '.........A..',
#  '............',
#  '............']

# %% [markdown]
# # Part 1
#
# find all instances of each letter/number
#
# for each letter, compute antinode locations based on every single unique pairing of nodes of that letter.
#
#   how to find the various pairings for a set of the same letters? SUM[n-1...1]
#   Start from first and pair with the next, go down the array to the end; then start from 2nd, go down the list, etc. until reach the 2nd to last value.
#
# Check if it'll be on the map or not, keep the valid ones.
#
# distance calculation is a delta_xy in both directions
#
# So if the 2 points are x1 = [5,7] and x2 = [9,10], the gap is x2-x1 = [4, 3]
#
# * [5,7] - [4, 3] = [1, 4] , aka x1-delta
# * [9,10] + [4, 3] = [13, 13], aka x2+delta

# %%
# class to store the grid, boundary validation function, delta calculator,

class Grid():
  def __init__(self, input_lines):
    self.grid = input_lines
    self.rows = len(input_lines)
    self.cols = len(input_lines[0])
    self.antinodes = set()
    self.towers = {} # { letter: list[ location_tuple ] }
    self.find_towers()

  def in_bounds(self, pos):
    x,y = pos
    return 0 <= x < self.rows and 0 <= y < self.cols

  def find_towers(self):
    for row in range(self.rows):
      for col in range(self.cols):
        loc_val = self.grid[row][col]
        if loc_val != '.':
          # if self.grid[row][col] not in self.towers:
          #   self.towers[self.grid[row][col]] = []
          location_list = self.towers.get(loc_val, [])
          location_list.append((row, col))
          self.towers[loc_val] = location_list

  def delta(self, x1, y1, x2, y2):
    return (x2-x1, y2-y1)

  def get_antinode(self, x1, y1, x2, y2):
    delta_x, delta_y = self.delta(x1, y1, x2, y2)
    return (x1-delta_x, y1-delta_y), (x2+delta_x, y2+delta_y)

  def tower_combos(self, tower_letter):
    tower_locations = self.towers[tower_letter]
    combos = []
    for i in range(len(tower_locations)-1):
      for j in range(i+1, len(tower_locations)):
        # print(i,j)
        combos.append((tower_locations[i], tower_locations[j]))
    return combos

  def find_antinodes(self):
    for tower_letter, tower_locations in self.towers.items():
      for (x1,y1),(x2, y2) in self.tower_combos(tower_letter):
        a, b = self.get_antinode(x1,y1,x2,y2)
        if self.in_bounds(a):
          self.antinodes.add(a)
        if self.in_bounds(b):
          self.antinodes.add(b)
    return self.antinodes

# %%
g = Grid(test_lines)

# %%
g.towers
# Out:
# {'0': [(1, 8), (2, 5), (3, 7), (4, 4)], 'A': [(5, 6), (8, 8), (9, 9)]}

# %%
g.tower_combos('A')
# Out:
# [((5, 6), (8, 8)), ((5, 6), (9, 9)), ((8, 8), (9, 9))]

# %%
(x1,y1),(x2, y2) = g.tower_combos('0')[4]

# %%
(x1,y1),(x2, y2)
# Out:
# ((2, 5), (4, 4))

# %%
(a1, b1), (a2, b2) = g.get_antinode(x1,y1,x2,y2)
(a1, b1), (a2, b2)
# Out:
# ((0, 6), (6, 3))

# %%
g.in_bounds((a1,b1)) , g.in_bounds((a2,b2))
# Out:
# (True, True)

# %%
antinodes = g.get_antinode(x1,y1,x2,y2)

# %%
list(map(g.in_bounds, antinodes))
# Out:
# [True, True]

# %%
an = g.find_antinodes()

# %%
an
# Out:
# {(0, 6),
#  (0, 11),
#  (1, 3),
#  (2, 4),
#  (2, 10),
#  (3, 2),
#  (4, 9),
#  (5, 1),
#  (5, 6),
#  (6, 3),
#  (7, 0),
#  (7, 7),
#  (10, 10),
#  (11, 10)}

# %%
g = Grid(input_lines)
an = g.find_antinodes()

len(an)
# Out:
# 291

# %% [markdown]
# # Part 2
#
# instead of creating 2 fixed antinodes, we now have antinodes propogating outwards as many times as needed to leave the map. Additionally, the antenna itself counts as a node, assuming there are at least 2 total.

# %%
# class to store the grid, boundary validation function, delta calculator,

class Grid():
  def __init__(self, input_lines):
    self.grid = input_lines
    self.rows = len(input_lines)
    self.cols = len(input_lines[0])
    self.antinodes = set()
    self.towers = {} # { letter: list[ location_tuple ] }
    self.find_towers()

  def in_bounds(self, pos):
    x,y = pos
    return 0 <= x < self.rows and 0 <= y < self.cols

  def find_towers(self):
    for row in range(self.rows):
      for col in range(self.cols):
        loc_val = self.grid[row][col]
        if loc_val != '.':
          # if self.grid[row][col] not in self.towers:
          #   self.towers[self.grid[row][col]] = []
          location_list = self.towers.get(loc_val, [])
          location_list.append((row, col))
          self.towers[loc_val] = location_list

  def delta(self, x1, y1, x2, y2):
    return (x2-x1, y2-y1)

  def get_antinode(self, x1, y1, x2, y2):
    delta_x, delta_y = self.delta(x1, y1, x2, y2)
    return (x1-delta_x, y1-delta_y), (x2+delta_x, y2+delta_y)

  def get_antinode_list(self, x1, y1, x2, y2):
    delta_x, delta_y = self.delta(x1, y1, x2, y2)
    # start with self and first order harmonics
    # x1_harmonic = (x1-delta_x, y1-delta_y)
    # x2_harmonic = (x2+delta_x, y2+delta_y)
    # antinodes = [(x1, y1), (x2, y2)]
    #  x1_harmonic, x2_harmonic]

    self.harmonize((x1,y1), (delta_x, delta_y), -1)
    self.harmonize((x2,y2), (delta_x, delta_y), 1)

    # test for more


  # direction is -1 or 1
  def harmonize(self, initial, delta, direction):
    print(f'harmonizing from {initial}, delta: {delta}, dir: {direction}')
    x1, y1 = initial
    x2, y2 = delta
    x2, y2 = x2*direction, y2*direction

    while self.in_bounds((x1,y1)):
      print(f'adding {x1,y1}')
      self.antinodes.add((x1,y1))
      x1, y1 = x1+x2, y1+y2 # move 1 delta jump

    return

  def tower_combos(self, tower_letter):
    tower_locations = self.towers[tower_letter]
    combos = []
    for i in range(len(tower_locations)-1):
      for j in range(i+1, len(tower_locations)):
        # print(i,j)
        combos.append((tower_locations[i], tower_locations[j]))
    return combos

  def find_antinodes(self):
    for tower_letter, tower_locations in self.towers.items():
      for (x1,y1),(x2, y2) in self.tower_combos(tower_letter):
        self.get_antinode_list( x1, y1, x2, y2)

        # a, b = self.get_antinode(x1,y1,x2,y2)
        # if self.in_bounds(a):
        #   self.antinodes.add(a)
        # if self.in_bounds(b):
        #   self.antinodes.add(b)
    return self.antinodes

# %%
g = Grid(input_lines)

# %%
g.find_antinodes()
# Out:
# harmonizing from (0, 3), delta: (7, 12), dir: -1
# adding (0, 3)
# harmonizing from (7, 15), delta: (7, 12), dir: 1
# adding (7, 15)
# adding (14, 27)
# adding (21, 39)
# harmonizing from (0, 3), delta: (10, 7), dir: -1
# adding (0, 3)
# harmonizing from (10, 10), delta: (10, 7), dir: 1
# adding (10, 10)
# adding (20, 17)
# adding (30, 24)
# adding (40, 31)
# harmonizing from (0, 3), delta: (17, 1), dir: -1
# adding (0, 3)
# harmonizing from (17, 4), delta: (17, 1), dir: 1
# adding (17, 4)
# adding (34, 5)
# harmonizing from (7, 15), delta: (3, -5), dir: -1
# adding (7, 15)
# adding (4, 20)
# adding (1, 25)
# harmonizing from (10, 10), delta: (3, -5), dir: 1
# adding (10, 10)
# adding (13, 5)
# adding (16, 0)
# harmonizing from (7, 15), delta: (10, -11), dir: -1
# adding (7, 15)
# harmonizing from (17, 4), delta: (10, -11), dir: 1
# adding (17, 4)
# harmonizing from (10, 10), delta: (7, -6), dir: -1
# adding (10, 10)
# adding (3, 16)
# harmonizing from (17, 4), delta: (7, -6), dir: 1
# adding (17, 4)
# harmonizing from (0, 32), delta: (1, 4), dir: -1
# adding (0, 32)
# harmonizing from (1, 36), delta: (1, 4), dir: 1
# adding (1, 36)
# adding (2, 40)
# adding (3, 44)
# adding (4, 48)
# harmonizing from (0, 32), delta: (8, 3), dir: -1
# adding (0, 32)
# harmonizing from (8, 35), delta: (8, 3), dir: 1
# adding (8, 35)
# adding (16, 38)
# adding (24, 41)
# adding (32, 44)
# adding (40, 47)
# harmonizing from (0, 32), delta: (9, -5), dir: -1
# adding (0, 32)
# harmonizing from (9, 27), delta: (9, -5), dir: 1
# adding (9, 27)
# adding (18, 22)
# adding (27, 17)
# adding (36, 12)
# adding (45, 7)
# harmonizing from (1, 36), delta: (7, -1), dir: -1
# adding (1, 36)
# harmonizing from (8, 35), delta: (7, -1), dir: 1
# adding (8, 35)
# adding (15, 34)
# adding (22, 33)
# adding (29, 32)
# adding (36, 31)
# adding (43, 30)
# harmonizing from (1, 36), delta: (8, -9), dir: -1
# adding (1, 36)
# harmonizing from (9, 27), delta: (8, -9), dir: 1
# adding (9, 27)
# adding (17, 18)
# adding (25, 9)
# adding (33, 0)
# harmonizing from (8, 35), delta: (1, -8), dir: -1
# adding (8, 35)
# adding (7, 43)
# harmonizing from (9, 27), delta: (1, -8), dir: 1
# adding (9, 27)
# adding (10, 19)
# adding (11, 11)
# adding (12, 3)
# harmonizing from (1, 6), delta: (5, -6), dir: -1
# adding (1, 6)
# harmonizing from (6, 0), delta: (5, -6), dir: 1
# adding (6, 0)
# harmonizing from (1, 6), delta: (7, 1), dir: -1
# adding (1, 6)
# harmonizing from (8, 7), delta: (7, 1), dir: 1
# adding (8, 7)
# adding (15, 8)
# adding (22, 9)
# adding (29, 10)
# adding (36, 11)
# adding (43, 12)
# harmonizing from (1, 6), delta: (10, -3), dir: -1
# adding (1, 6)
# harmonizing from (11, 3), delta: (10, -3), dir: 1
# adding (11, 3)
# adding (21, 0)
# harmonizing from (6, 0), delta: (2, 7), dir: -1
# adding (6, 0)
# harmonizing from (8, 7), delta: (2, 7), dir: 1
# adding (8, 7)
# adding (10, 14)
# adding (12, 21)
# adding (14, 28)
# adding (16, 35)
# adding (18, 42)
# adding (20, 49)
# harmonizing from (6, 0), delta: (5, 3), dir: -1
# adding (6, 0)
# harmonizing from (11, 3), delta: (5, 3), dir: 1
# adding (11, 3)
# adding (16, 6)
# adding (21, 9)
# adding (26, 12)
# adding (31, 15)
# adding (36, 18)
# adding (41, 21)
# adding (46, 24)
# harmonizing from (8, 7), delta: (3, -4), dir: -1
# adding (8, 7)
# adding (5, 11)
# adding (2, 15)
# harmonizing from (11, 3), delta: (3, -4), dir: 1
# adding (11, 3)
# harmonizing from (2, 10), delta: (3, -1), dir: -1
# adding (2, 10)
# harmonizing from (5, 9), delta: (3, -1), dir: 1
# adding (5, 9)
# adding (8, 8)
# adding (11, 7)
# adding (14, 6)
# adding (17, 5)
# adding (20, 4)
# adding (23, 3)
# adding (26, 2)
# adding (29, 1)
# adding (32, 0)
# harmonizing from (2, 10), delta: (7, 6), dir: -1
# adding (2, 10)
# harmonizing from (9, 16), delta: (7, 6), dir: 1
# adding (9, 16)
# adding (16, 22)
# adding (23, 28)
# adding (30, 34)
# adding (37, 40)
# adding (44, 46)
# harmonizing from (2, 10), delta: (32, 3), dir: -1
# adding (2, 10)
# harmonizing from (34, 13), delta: (32, 3), dir: 1
# adding (34, 13)
# harmonizing from (5, 9), delta: (4, 7), dir: -1
# adding (5, 9)
# adding (1, 2)
# harmonizing from (9, 16), delta: (4, 7), dir: 1
# adding (9, 16)
# adding (13, 23)
# adding (17, 30)
# adding (21, 37)
# adding (25, 44)
# harmonizing from (5, 9), delta: (29, 4), dir: -1
# adding (5, 9)
# harmonizing from (34, 13), delta: (29, 4), dir: 1
# adding (34, 13)
# harmonizing from (9, 16), delta: (25, -3), dir: -1
# adding (9, 16)
# harmonizing from (34, 13), delta: (25, -3), dir: 1
# adding (34, 13)
# harmonizing from (2, 23), delta: (1, 2), dir: -1
# adding (2, 23)
# adding (1, 21)
# adding (0, 19)
# harmonizing from (3, 25), delta: (1, 2), dir: 1
# adding (3, 25)
# adding (4, 27)
# adding (5, 29)
# adding (6, 31)
# adding (7, 33)
# adding (8, 35)
# adding (9, 37)
# adding (10, 39)
# adding (11, 41)
# adding (12, 43)
# adding (13, 45)
# adding (14, 47)
# adding (15, 49)
# harmonizing from (2, 23), delta: (8, -1), dir: -1
# adding (2, 23)
# harmonizing from (10, 22), delta: (8, -1), dir: 1
# adding (10, 22)
# adding (18, 21)
# adding (26, 20)
# adding (34, 19)
# adding (42, 18)
# harmonizing from (2, 23), delta: (15, 1), dir: -1
# adding (2, 23)
# harmonizing from (17, 24), delta: (15, 1), dir: 1
# adding (17, 24)
# adding (32, 25)
# adding (47, 26)
# harmonizing from (3, 25), delta: (7, -3), dir: -1
# adding (3, 25)
# harmonizing from (10, 22), delta: (7, -3), dir: 1
# adding (10, 22)
# adding (17, 19)
# adding (24, 16)
# adding (31, 13)
# adding (38, 10)
# adding (45, 7)
# harmonizing from (3, 25), delta: (14, -1), dir: -1
# adding (3, 25)
# harmonizing from (17, 24), delta: (14, -1), dir: 1
# adding (17, 24)
# adding (31, 23)
# adding (45, 22)
# harmonizing from (10, 22), delta: (7, 2), dir: -1
# adding (10, 22)
# adding (3, 20)
# harmonizing from (17, 24), delta: (7, 2), dir: 1
# adding (17, 24)
# adding (24, 26)
# adding (31, 28)
# adding (38, 30)
# adding (45, 32)
# harmonizing from (3, 24), delta: (9, 1), dir: -1
# adding (3, 24)
# harmonizing from (12, 25), delta: (9, 1), dir: 1
# adding (12, 25)
# adding (21, 26)
# adding (30, 27)
# adding (39, 28)
# adding (48, 29)
# harmonizing from (3, 24), delta: (13, -2), dir: -1
# adding (3, 24)
# harmonizing from (16, 22), delta: (13, -2), dir: 1
# adding (16, 22)
# adding (29, 20)
# adding (42, 18)
# harmonizing from (3, 24), delta: (22, 5), dir: -1
# adding (3, 24)
# harmonizing from (25, 29), delta: (22, 5), dir: 1
# adding (25, 29)
# adding (47, 34)
# harmonizing from (12, 25), delta: (4, -3), dir: -1
# adding (12, 25)
# adding (8, 28)
# adding (4, 31)
# adding (0, 34)
# harmonizing from (16, 22), delta: (4, -3), dir: 1
# adding (16, 22)
# adding (20, 19)
# adding (24, 16)
# adding (28, 13)
# adding (32, 10)
# adding (36, 7)
# adding (40, 4)
# adding (44, 1)
# harmonizing from (12, 25), delta: (13, 4), dir: -1
# adding (12, 25)
# harmonizing from (25, 29), delta: (13, 4), dir: 1
# adding (25, 29)
# adding (38, 33)
# harmonizing from (16, 22), delta: (9, 7), dir: -1
# adding (16, 22)
# adding (7, 15)
# harmonizing from (25, 29), delta: (9, 7), dir: 1
# adding (25, 29)
# adding (34, 36)
# adding (43, 43)
# harmonizing from (6, 27), delta: (5, 4), dir: -1
# adding (6, 27)
# adding (1, 23)
# harmonizing from (11, 31), delta: (5, 4), dir: 1
# adding (11, 31)
# adding (16, 35)
# adding (21, 39)
# adding (26, 43)
# adding (31, 47)
# harmonizing from (6, 27), delta: (7, -5), dir: -1
# adding (6, 27)
# harmonizing from (13, 22), delta: (7, -5), dir: 1
# adding (13, 22)
# adding (20, 17)
# adding (27, 12)
# adding (34, 7)
# adding (41, 2)
# harmonizing from (6, 27), delta: (8, -3), dir: -1
# adding (6, 27)
# harmonizing from (14, 24), delta: (8, -3), dir: 1
# adding (14, 24)
# adding (22, 21)
# adding (30, 18)
# adding (38, 15)
# adding (46, 12)
# harmonizing from (11, 31), delta: (2, -9), dir: -1
# adding (11, 31)
# adding (9, 40)
# adding (7, 49)
# harmonizing from (13, 22), delta: (2, -9), dir: 1
# adding (13, 22)
# adding (15, 13)
# adding (17, 4)
# harmonizing from (11, 31), delta: (3, -7), dir: -1
# adding (11, 31)
# adding (8, 38)
# adding (5, 45)
# harmonizing from (14, 24), delta: (3, -7), dir: 1
# adding (14, 24)
# adding (17, 17)
# adding (20, 10)
# adding (23, 3)
# harmonizing from (13, 22), delta: (1, 2), dir: -1
# adding (13, 22)
# adding (12, 20)
# adding (11, 18)
# adding (10, 16)
# adding (9, 14)
# adding (8, 12)
# adding (7, 10)
# adding (6, 8)
# adding (5, 6)
# adding (4, 4)
# adding (3, 2)
# adding (2, 0)
# harmonizing from (14, 24), delta: (1, 2), dir: 1
# adding (14, 24)
# adding (15, 26)
# adding (16, 28)
# adding (17, 30)
# adding (18, 32)
# adding (19, 34)
# adding (20, 36)
# adding (21, 38)
# adding (22, 40)
# adding (23, 42)
# adding (24, 44)
# adding (25, 46)
# adding (26, 48)
# harmonizing from (6, 45), delta: (3, -4), dir: -1
# adding (6, 45)
# adding (3, 49)
# harmonizing from (9, 41), delta: (3, -4), dir: 1
# adding (9, 41)
# adding (12, 37)
# adding (15, 33)
# adding (18, 29)
# adding (21, 25)
# adding (24, 21)
# adding (27, 17)
# adding (30, 13)
# adding (33, 9)
# adding (36, 5)
# adding (39, 1)
# harmonizing from (6, 45), delta: (4, -15), dir: -1
# adding (6, 45)
# harmonizing from (10, 30), delta: (4, -15), dir: 1
# adding (10, 30)
# adding (14, 15)
# adding (18, 0)
# harmonizing from (6, 45), delta: (7, -1), dir: -1
# adding (6, 45)
# harmonizing from (13, 44), delta: (7, -1), dir: 1
# adding (13, 44)
# adding (20, 43)
# adding (27, 42)
# adding (34, 41)
# adding (41, 40)
# adding (48, 39)
# harmonizing from (9, 41), delta: (1, -11), dir: -1
# adding (9, 41)
# harmonizing from (10, 30), delta: (1, -11), dir: 1
# adding (10, 30)
# adding (11, 19)
# adding (12, 8)
# harmonizing from (9, 41), delta: (4, 3), dir: -1
# adding (9, 41)
# adding (5, 38)
# adding (1, 35)
# harmonizing from (13, 44), delta: (4, 3), dir: 1
# adding (13, 44)
# adding (17, 47)
# harmonizing from (10, 30), delta: (3, 14), dir: -1
# adding (10, 30)
# adding (7, 16)
# adding (4, 2)
# harmonizing from (13, 44), delta: (3, 14), dir: 1
# adding (13, 44)
# harmonizing from (7, 3), delta: (9, 23), dir: -1
# adding (7, 3)
# harmonizing from (16, 26), delta: (9, 23), dir: 1
# adding (16, 26)
# adding (25, 49)
# harmonizing from (7, 3), delta: (14, 25), dir: -1
# adding (7, 3)
# harmonizing from (21, 28), delta: (14, 25), dir: 1
# adding (21, 28)
# harmonizing from (7, 3), delta: (17, 18), dir: -1
# adding (7, 3)
# harmonizing from (24, 21), delta: (17, 18), dir: 1
# adding (24, 21)
# adding (41, 39)
# harmonizing from (16, 26), delta: (5, 2), dir: -1
# adding (16, 26)
# adding (11, 24)
# adding (6, 22)
# adding (1, 20)
# harmonizing from (21, 28), delta: (5, 2), dir: 1
# adding (21, 28)
# adding (26, 30)
# adding (31, 32)
# adding (36, 34)
# adding (41, 36)
# adding (46, 38)
# harmonizing from (16, 26), delta: (8, -5), dir: -1
# adding (16, 26)
# adding (8, 31)
# adding (0, 36)
# harmonizing from (24, 21), delta: (8, -5), dir: 1
# adding (24, 21)
# adding (32, 16)
# adding (40, 11)
# adding (48, 6)
# harmonizing from (21, 28), delta: (3, -7), dir: -1
# adding (21, 28)
# adding (18, 35)
# adding (15, 42)
# adding (12, 49)
# harmonizing from (24, 21), delta: (3, -7), dir: 1
# adding (24, 21)
# adding (27, 14)
# adding (30, 7)
# adding (33, 0)
# harmonizing from (7, 7), delta: (1, -2), dir: -1
# adding (7, 7)
# adding (6, 9)
# adding (5, 11)
# adding (4, 13)
# adding (3, 15)
# adding (2, 17)
# adding (1, 19)
# adding (0, 21)
# harmonizing from (8, 5), delta: (1, -2), dir: 1
# adding (8, 5)
# adding (9, 3)
# adding (10, 1)
# harmonizing from (7, 7), delta: (5, -1), dir: -1
# adding (7, 7)
# adding (2, 8)
# harmonizing from (12, 6), delta: (5, -1), dir: 1
# adding (12, 6)
# adding (17, 5)
# adding (22, 4)
# adding (27, 3)
# adding (32, 2)
# adding (37, 1)
# adding (42, 0)
# harmonizing from (7, 7), delta: (8, 1), dir: -1
# adding (7, 7)
# harmonizing from (15, 8), delta: (8, 1), dir: 1
# adding (15, 8)
# adding (23, 9)
# adding (31, 10)
# adding (39, 11)
# adding (47, 12)
# harmonizing from (8, 5), delta: (4, 1), dir: -1
# adding (8, 5)
# adding (4, 4)
# adding (0, 3)
# harmonizing from (12, 6), delta: (4, 1), dir: 1
# adding (12, 6)
# adding (16, 7)
# adding (20, 8)
# adding (24, 9)
# adding (28, 10)
# adding (32, 11)
# adding (36, 12)
# adding (40, 13)
# adding (44, 14)
# adding (48, 15)
# harmonizing from (8, 5), delta: (7, 3), dir: -1
# adding (8, 5)
# adding (1, 2)
# harmonizing from (15, 8), delta: (7, 3), dir: 1
# adding (15, 8)
# adding (22, 11)
# adding (29, 14)
# adding (36, 17)
# adding (43, 20)
# harmonizing from (12, 6), delta: (3, 2), dir: -1
# adding (12, 6)
# adding (9, 4)
# adding (6, 2)
# adding (3, 0)
# harmonizing from (15, 8), delta: (3, 2), dir: 1
# adding (15, 8)
# adding (18, 10)
# adding (21, 12)
# adding (24, 14)
# adding (27, 16)
# adding (30, 18)
# adding (33, 20)
# adding (36, 22)
# adding (39, 24)
# adding (42, 26)
# adding (45, 28)
# adding (48, 30)
# harmonizing from (7, 43), delta: (5, -1), dir: -1
# adding (7, 43)
# adding (2, 44)
# harmonizing from (12, 42), delta: (5, -1), dir: 1
# adding (12, 42)
# adding (17, 41)
# adding (22, 40)
# adding (27, 39)
# adding (32, 38)
# adding (37, 37)
# adding (42, 36)
# adding (47, 35)
# harmonizing from (7, 43), delta: (13, -8), dir: -1
# adding (7, 43)
# harmonizing from (20, 35), delta: (13, -8), dir: 1
# adding (20, 35)
# adding (33, 27)
# adding (46, 19)
# harmonizing from (7, 43), delta: (40, -7), dir: -1
# adding (7, 43)
# harmonizing from (47, 36), delta: (40, -7), dir: 1
# adding (47, 36)
# harmonizing from (12, 42), delta: (8, -7), dir: -1
# adding (12, 42)
# adding (4, 49)
# harmonizing from (20, 35), delta: (8, -7), dir: 1
# adding (20, 35)
# adding (28, 28)
# adding (36, 21)
# adding (44, 14)
# harmonizing from (12, 42), delta: (35, -6), dir: -1
# adding (12, 42)
# harmonizing from (47, 36), delta: (35, -6), dir: 1
# adding (47, 36)
# harmonizing from (20, 35), delta: (27, 1), dir: -1
# adding (20, 35)
# harmonizing from (47, 36), delta: (27, 1), dir: 1
# adding (47, 36)
# harmonizing from (8, 42), delta: (1, 1), dir: -1
# adding (8, 42)
# adding (7, 41)
# adding (6, 40)
# adding (5, 39)
# adding (4, 38)
# adding (3, 37)
# adding (2, 36)
# adding (1, 35)
# adding (0, 34)
# harmonizing from (9, 43), delta: (1, 1), dir: 1
# adding (9, 43)
# adding (10, 44)
# adding (11, 45)
# adding (12, 46)
# adding (13, 47)
# adding (14, 48)
# adding (15, 49)
# harmonizing from (8, 42), delta: (14, -5), dir: -1
# adding (8, 42)
# harmonizing from (22, 37), delta: (14, -5), dir: 1
# adding (22, 37)
# adding (36, 32)
# harmonizing from (9, 43), delta: (13, -6), dir: -1
# adding (9, 43)
# harmonizing from (22, 37), delta: (13, -6), dir: 1
# adding (22, 37)
# adding (35, 31)
# adding (48, 25)
# harmonizing from (9, 21), delta: (1, -9), dir: -1
# adding (9, 21)
# adding (8, 30)
# adding (7, 39)
# adding (6, 48)
# harmonizing from (10, 12), delta: (1, -9), dir: 1
# adding (10, 12)
# adding (11, 3)
# harmonizing from (9, 21), delta: (2, -7), dir: -1
# adding (9, 21)
# adding (7, 28)
# adding (5, 35)
# adding (3, 42)
# adding (1, 49)
# harmonizing from (11, 14), delta: (2, -7), dir: 1
# adding (11, 14)
# adding (13, 7)
# adding (15, 0)
# harmonizing from (9, 21), delta: (7, 2), dir: -1
# adding (9, 21)
# adding (2, 19)
# harmonizing from (16, 23), delta: (7, 2), dir: 1
# adding (16, 23)
# adding (23, 25)
# adding (30, 27)
# adding (37, 29)
# adding (44, 31)
# harmonizing from (10, 12), delta: (1, 2), dir: -1
# adding (10, 12)
# adding (9, 10)
# adding (8, 8)
# adding (7, 6)
# adding (6, 4)
# adding (5, 2)
# adding (4, 0)
# harmonizing from (11, 14), delta: (1, 2), dir: 1
# adding (11, 14)
# adding (12, 16)
# adding (13, 18)
# adding (14, 20)
# adding (15, 22)
# adding (16, 24)
# adding (17, 26)
# adding (18, 28)
# adding (19, 30)
# adding (20, 32)
# adding (21, 34)
# adding (22, 36)
# adding (23, 38)
# adding (24, 40)
# adding (25, 42)
# adding (26, 44)
# adding (27, 46)
# adding (28, 48)
# harmonizing from (10, 12), delta: (6, 11), dir: -1
# adding (10, 12)
# adding (4, 1)
# harmonizing from (16, 23), delta: (6, 11), dir: 1
# adding (16, 23)
# adding (22, 34)
# adding (28, 45)
# harmonizing from (11, 14), delta: (5, 9), dir: -1
# adding (11, 14)
# adding (6, 5)
# harmonizing from (16, 23), delta: (5, 9), dir: 1
# adding (16, 23)
# adding (21, 32)
# adding (26, 41)
# harmonizing from (10, 25), delta: (1, 9), dir: -1
# adding (10, 25)
# adding (9, 16)
# adding (8, 7)
# harmonizing from (11, 34), delta: (1, 9), dir: 1
# adding (11, 34)
# adding (12, 43)
# harmonizing from (10, 25), delta: (8, 13), dir: -1
# adding (10, 25)
# adding (2, 12)
# harmonizing from (18, 38), delta: (8, 13), dir: 1
# adding (18, 38)
# harmonizing from (10, 25), delta: (19, 16), dir: -1
# adding (10, 25)
# harmonizing from (29, 41), delta: (19, 16), dir: 1
# adding (29, 41)
# harmonizing from (11, 34), delta: (7, 4), dir: -1
# adding (11, 34)
# adding (4, 30)
# harmonizing from (18, 38), delta: (7, 4), dir: 1
# adding (18, 38)
# adding (25, 42)
# adding (32, 46)
# harmonizing from (11, 34), delta: (18, 7), dir: -1
# adding (11, 34)
# harmonizing from (29, 41), delta: (18, 7), dir: 1
# adding (29, 41)
# adding (47, 48)
# harmonizing from (18, 38), delta: (11, 3), dir: -1
# adding (18, 38)
# adding (7, 35)
# harmonizing from (29, 41), delta: (11, 3), dir: 1
# adding (29, 41)
# adding (40, 44)
# harmonizing from (11, 9), delta: (18, -7), dir: -1
# adding (11, 9)
# harmonizing from (29, 2), delta: (18, -7), dir: 1
# adding (29, 2)
# harmonizing from (11, 9), delta: (21, -8), dir: -1
# adding (11, 9)
# harmonizing from (32, 1), delta: (21, -8), dir: 1
# adding (32, 1)
# harmonizing from (11, 9), delta: (23, -5), dir: -1
# adding (11, 9)
# harmonizing from (34, 4), delta: (23, -5), dir: 1
# adding (34, 4)
# harmonizing from (29, 2), delta: (3, -1), dir: -1
# adding (29, 2)
# adding (26, 3)
# adding (23, 4)
# adding (20, 5)
# adding (17, 6)
# adding (14, 7)
# adding (11, 8)
# adding (8, 9)
# adding (5, 10)
# adding (2, 11)
# harmonizing from (32, 1), delta: (3, -1), dir: 1
# adding (32, 1)
# adding (35, 0)
# harmonizing from (29, 2), delta: (5, 2), dir: -1
# adding (29, 2)
# adding (24, 0)
# harmonizing from (34, 4), delta: (5, 2), dir: 1
# adding (34, 4)
# adding (39, 6)
# adding (44, 8)
# adding (49, 10)
# harmonizing from (32, 1), delta: (2, 3), dir: -1
# adding (32, 1)
# harmonizing from (34, 4), delta: (2, 3), dir: 1
# adding (34, 4)
# adding (36, 7)
# adding (38, 10)
# adding (40, 13)
# adding (42, 16)
# adding (44, 19)
# adding (46, 22)
# adding (48, 25)
# harmonizing from (12, 13), delta: (3, 14), dir: -1
# adding (12, 13)
# harmonizing from (15, 27), delta: (3, 14), dir: 1
# adding (15, 27)
# adding (18, 41)
# harmonizing from (12, 13), delta: (4, 1), dir: -1
# adding (12, 13)
# adding (8, 12)
# adding (4, 11)
# adding (0, 10)
# harmonizing from (16, 14), delta: (4, 1), dir: 1
# adding (16, 14)
# adding (20, 15)
# adding (24, 16)
# adding (28, 17)
# adding (32, 18)
# adding (36, 19)
# adding (40, 20)
# adding (44, 21)
# adding (48, 22)
# harmonizing from (12, 13), delta: (13, 23), dir: -1
# adding (12, 13)
# harmonizing from (25, 36), delta: (13, 23), dir: 1
# adding (25, 36)
# harmonizing from (15, 27), delta: (1, -13), dir: -1
# adding (15, 27)
# adding (14, 40)
# harmonizing from (16, 14), delta: (1, -13), dir: 1
# adding (16, 14)
# adding (17, 1)
# harmonizing from (15, 27), delta: (10, 9), dir: -1
# adding (15, 27)
# adding (5, 18)
# harmonizing from (25, 36), delta: (10, 9), dir: 1
# adding (25, 36)
# adding (35, 45)
# harmonizing from (16, 14), delta: (9, 22), dir: -1
# adding (16, 14)
# harmonizing from (25, 36), delta: (9, 22), dir: 1
# adding (25, 36)
# harmonizing from (13, 41), delta: (11, 4), dir: -1
# adding (13, 41)
# adding (2, 37)
# harmonizing from (24, 45), delta: (11, 4), dir: 1
# adding (24, 45)
# adding (35, 49)
# harmonizing from (13, 41), delta: (13, 3), dir: -1
# adding (13, 41)
# adding (0, 38)
# harmonizing from (26, 44), delta: (13, 3), dir: 1
# adding (26, 44)
# adding (39, 47)
# harmonizing from (13, 41), delta: (14, -1), dir: -1
# adding (13, 41)
# harmonizing from (27, 40), delta: (14, -1), dir: 1
# adding (27, 40)
# adding (41, 39)
# harmonizing from (24, 45), delta: (2, -1), dir: -1
# adding (24, 45)
# adding (22, 46)
# adding (20, 47)
# adding (18, 48)
# adding (16, 49)
# harmonizing from (26, 44), delta: (2, -1), dir: 1
# adding (26, 44)
# adding (28, 43)
# adding (30, 42)
# adding (32, 41)
# adding (34, 40)
# adding (36, 39)
# adding (38, 38)
# adding (40, 37)
# adding (42, 36)
# adding (44, 35)
# adding (46, 34)
# adding (48, 33)
# harmonizing from (24, 45), delta: (3, -5), dir: -1
# adding (24, 45)
# harmonizing from (27, 40), delta: (3, -5), dir: 1
# adding (27, 40)
# adding (30, 35)
# adding (33, 30)
# adding (36, 25)
# adding (39, 20)
# adding (42, 15)
# adding (45, 10)
# adding (48, 5)
# harmonizing from (26, 44), delta: (1, -4), dir: -1
# adding (26, 44)
# adding (25, 48)
# harmonizing from (27, 40), delta: (1, -4), dir: 1
# adding (27, 40)
# adding (28, 36)
# adding (29, 32)
# adding (30, 28)
# adding (31, 24)
# adding (32, 20)
# adding (33, 16)
# adding (34, 12)
# adding (35, 8)
# adding (36, 4)
# adding (37, 0)
# harmonizing from (14, 33), delta: (5, 7), dir: -1
# adding (14, 33)
# adding (9, 26)
# adding (4, 19)
# harmonizing from (19, 40), delta: (5, 7), dir: 1
# adding (19, 40)
# adding (24, 47)
# harmonizing from (14, 33), delta: (6, -5), dir: -1
# adding (14, 33)
# adding (8, 38)
# adding (2, 43)
# harmonizing from (20, 28), delta: (6, -5), dir: 1
# adding (20, 28)
# adding (26, 23)
# adding (32, 18)
# adding (38, 13)
# adding (44, 8)
# harmonizing from (14, 33), delta: (7, -8), dir: -1
# adding (14, 33)
# adding (7, 41)
# adding (0, 49)
# harmonizing from (21, 25), delta: (7, -8), dir: 1
# adding (21, 25)
# adding (28, 17)
# adding (35, 9)
# adding (42, 1)
# harmonizing from (19, 40), delta: (1, -12), dir: -1
# adding (19, 40)
# harmonizing from (20, 28), delta: (1, -12), dir: 1
# adding (20, 28)
# adding (21, 16)
# adding (22, 4)
# harmonizing from (19, 40), delta: (2, -15), dir: -1
# adding (19, 40)
# harmonizing from (21, 25), delta: (2, -15), dir: 1
# adding (21, 25)
# adding (23, 10)
# harmonizing from (20, 28), delta: (1, -3), dir: -1
# adding (20, 28)
# adding (19, 31)
# adding (18, 34)
# adding (17, 37)
# adding (16, 40)
# adding (15, 43)
# adding (14, 46)
# adding (13, 49)
# harmonizing from (21, 25), delta: (1, -3), dir: 1
# adding (21, 25)
# adding (22, 22)
# adding (23, 19)
# adding (24, 16)
# adding (25, 13)
# adding (26, 10)
# adding (27, 7)
# adding (28, 4)
# adding (29, 1)
# harmonizing from (16, 7), delta: (1, 1), dir: -1
# adding (16, 7)
# adding (15, 6)
# adding (14, 5)
# adding (13, 4)
# adding (12, 3)
# adding (11, 2)
# adding (10, 1)
# adding (9, 0)
# harmonizing from (17, 8), delta: (1, 1), dir: 1
# adding (17, 8)
# adding (18, 9)
# adding (19, 10)
# adding (20, 11)
# adding (21, 12)
# adding (22, 13)
# adding (23, 14)
# adding (24, 15)
# adding (25, 16)
# adding (26, 17)
# adding (27, 18)
# adding (28, 19)
# adding (29, 20)
# adding (30, 21)
# adding (31, 22)
# adding (32, 23)
# adding (33, 24)
# adding (34, 25)
# adding (35, 26)
# adding (36, 27)
# adding (37, 28)
# adding (38, 29)
# adding (39, 30)
# adding (40, 31)
# adding (41, 32)
# adding (42, 33)
# adding (43, 34)
# adding (44, 35)
# adding (45, 36)
# adding (46, 37)
# adding (47, 38)
# adding (48, 39)
# adding (49, 40)
# harmonizing from (16, 7), delta: (14, 15), dir: -1
# adding (16, 7)
# harmonizing from (30, 22), delta: (14, 15), dir: 1
# adding (30, 22)
# adding (44, 37)
# harmonizing from (16, 7), delta: (23, 16), dir: -1
# adding (16, 7)
# harmonizing from (39, 23), delta: (23, 16), dir: 1
# adding (39, 23)
# harmonizing from (17, 8), delta: (13, 14), dir: -1
# adding (17, 8)
# harmonizing from (30, 22), delta: (13, 14), dir: 1
# adding (30, 22)
# adding (43, 36)
# harmonizing from (17, 8), delta: (22, 15), dir: -1
# adding (17, 8)
# harmonizing from (39, 23), delta: (22, 15), dir: 1
# adding (39, 23)
# harmonizing from (30, 22), delta: (9, 1), dir: -1
# adding (30, 22)
# adding (21, 21)
# adding (12, 20)
# adding (3, 19)
# harmonizing from (39, 23), delta: (9, 1), dir: 1
# adding (39, 23)
# adding (48, 24)
# harmonizing from (16, 9), delta: (1, -4), dir: -1
# adding (16, 9)
# adding (15, 13)
# adding (14, 17)
# adding (13, 21)
# adding (12, 25)
# adding (11, 29)
# adding (10, 33)
# adding (9, 37)
# adding (8, 41)
# adding (7, 45)
# adding (6, 49)
# harmonizing from (17, 5), delta: (1, -4), dir: 1
# adding (17, 5)
# adding (18, 1)
# harmonizing from (16, 9), delta: (9, -5), dir: -1
# adding (16, 9)
# adding (7, 14)
# harmonizing from (25, 4), delta: (9, -5), dir: 1
# adding (25, 4)
# harmonizing from (16, 9), delta: (14, 19), dir: -1
# adding (16, 9)
# harmonizing from (30, 28), delta: (14, 19), dir: 1
# adding (30, 28)
# adding (44, 47)
# harmonizing from (17, 5), delta: (8, -1), dir: -1
# adding (17, 5)
# adding (9, 6)
# adding (1, 7)
# harmonizing from (25, 4), delta: (8, -1), dir: 1
# adding (25, 4)
# adding (33, 3)
# adding (41, 2)
# adding (49, 1)
# harmonizing from (17, 5), delta: (13, 23), dir: -1
# adding (17, 5)
# harmonizing from (30, 28), delta: (13, 23), dir: 1
# adding (30, 28)
# harmonizing from (25, 4), delta: (5, 24), dir: -1
# adding (25, 4)
# harmonizing from (30, 28), delta: (5, 24), dir: 1
# adding (30, 28)
# harmonizing from (16, 36), delta: (11, -6), dir: -1
# adding (16, 36)
# adding (5, 42)
# harmonizing from (27, 30), delta: (11, -6), dir: 1
# adding (27, 30)
# adding (38, 24)
# adding (49, 18)
# harmonizing from (16, 36), delta: (19, 5), dir: -1
# adding (16, 36)
# harmonizing from (35, 41), delta: (19, 5), dir: 1
# adding (35, 41)
# harmonizing from (16, 36), delta: (20, 11), dir: -1
# adding (16, 36)
# harmonizing from (36, 47), delta: (20, 11), dir: 1
# adding (36, 47)
# harmonizing from (27, 30), delta: (8, 11), dir: -1
# adding (27, 30)
# adding (19, 19)
# adding (11, 8)
# harmonizing from (35, 41), delta: (8, 11), dir: 1
# adding (35, 41)
# harmonizing from (27, 30), delta: (9, 17), dir: -1
# adding (27, 30)
# adding (18, 13)
# harmonizing from (36, 47), delta: (9, 17), dir: 1
# adding (36, 47)
# harmonizing from (35, 41), delta: (1, 6), dir: -1
# adding (35, 41)
# adding (34, 35)
# adding (33, 29)
# adding (32, 23)
# adding (31, 17)
# adding (30, 11)
# adding (29, 5)
# harmonizing from (36, 47), delta: (1, 6), dir: 1
# adding (36, 47)
# harmonizing from (17, 0), delta: (1, 21), dir: -1
# adding (17, 0)
# harmonizing from (18, 21), delta: (1, 21), dir: 1
# adding (18, 21)
# adding (19, 42)
# harmonizing from (17, 0), delta: (3, 8), dir: -1
# adding (17, 0)
# harmonizing from (20, 8), delta: (3, 8), dir: 1
# adding (20, 8)
# adding (23, 16)
# adding (26, 24)
# adding (29, 32)
# adding (32, 40)
# adding (35, 48)
# harmonizing from (17, 0), delta: (16, 17), dir: -1
# adding (17, 0)
# harmonizing from (33, 17), delta: (16, 17), dir: 1
# adding (33, 17)
# adding (49, 34)
# harmonizing from (18, 21), delta: (2, -13), dir: -1
# adding (18, 21)
# adding (16, 34)
# adding (14, 47)
# harmonizing from (20, 8), delta: (2, -13), dir: 1
# adding (20, 8)
# harmonizing from (18, 21), delta: (15, -4), dir: -1
# adding (18, 21)
# adding (3, 25)
# harmonizing from (33, 17), delta: (15, -4), dir: 1
# adding (33, 17)
# adding (48, 13)
# harmonizing from (20, 8), delta: (13, 9), dir: -1
# adding (20, 8)
# harmonizing from (33, 17), delta: (13, 9), dir: 1
# adding (33, 17)
# adding (46, 26)
# harmonizing from (18, 5), delta: (3, -1), dir: -1
# adding (18, 5)
# adding (15, 6)
# adding (12, 7)
# adding (9, 8)
# adding (6, 9)
# adding (3, 10)
# adding (0, 11)
# harmonizing from (21, 4), delta: (3, -1), dir: 1
# adding (21, 4)
# adding (24, 3)
# adding (27, 2)
# adding (30, 1)
# adding (33, 0)
# harmonizing from (18, 5), delta: (7, 4), dir: -1
# adding (18, 5)
# adding (11, 1)
# harmonizing from (25, 9), delta: (7, 4), dir: 1
# adding (25, 9)
# adding (32, 13)
# adding (39, 17)
# adding (46, 21)
# harmonizing from (18, 5), delta: (8, -5), dir: -1
# adding (18, 5)
# adding (10, 10)
# adding (2, 15)
# harmonizing from (26, 0), delta: (8, -5), dir: 1
# adding (26, 0)
# harmonizing from (21, 4), delta: (4, 5), dir: -1
# adding (21, 4)
# harmonizing from (25, 9), delta: (4, 5), dir: 1
# adding (25, 9)
# adding (29, 14)
# adding (33, 19)
# adding (37, 24)
# adding (41, 29)
# adding (45, 34)
# adding (49, 39)
# harmonizing from (21, 4), delta: (5, -4), dir: -1
# adding (21, 4)
# adding (16, 8)
# adding (11, 12)
# adding (6, 16)
# adding (1, 20)
# harmonizing from (26, 0), delta: (5, -4), dir: 1
# adding (26, 0)
# harmonizing from (25, 9), delta: (1, -9), dir: -1
# adding (25, 9)
# adding (24, 18)
# adding (23, 27)
# adding (22, 36)
# adding (21, 45)
# harmonizing from (26, 0), delta: (1, -9), dir: 1
# adding (26, 0)
# harmonizing from (18, 19), delta: (21, 20), dir: -1
# adding (18, 19)
# harmonizing from (39, 39), delta: (21, 20), dir: 1
# adding (39, 39)
# harmonizing from (18, 19), delta: (23, 25), dir: -1
# adding (18, 19)
# harmonizing from (41, 44), delta: (23, 25), dir: 1
# adding (41, 44)
# harmonizing from (18, 19), delta: (30, 13), dir: -1
# adding (18, 19)
# harmonizing from (48, 32), delta: (30, 13), dir: 1
# adding (48, 32)
# harmonizing from (39, 39), delta: (2, 5), dir: -1
# adding (39, 39)
# adding (37, 34)
# adding (35, 29)
# adding (33, 24)
# adding (31, 19)
# adding (29, 14)
# adding (27, 9)
# adding (25, 4)
# harmonizing from (41, 44), delta: (2, 5), dir: 1
# adding (41, 44)
# adding (43, 49)
# harmonizing from (39, 39), delta: (9, -7), dir: -1
# adding (39, 39)
# adding (30, 46)
# harmonizing from (48, 32), delta: (9, -7), dir: 1
# adding (48, 32)
# harmonizing from (41, 44), delta: (7, -12), dir: -1
# adding (41, 44)
# harmonizing from (48, 32), delta: (7, -12), dir: 1
# adding (48, 32)
# harmonizing from (18, 20), delta: (19, 24), dir: -1
# adding (18, 20)
# harmonizing from (37, 44), delta: (19, 24), dir: 1
# adding (37, 44)
# harmonizing from (18, 20), delta: (24, 25), dir: -1
# adding (18, 20)
# harmonizing from (42, 45), delta: (24, 25), dir: 1
# adding (42, 45)
# harmonizing from (18, 20), delta: (29, 17), dir: -1
# adding (18, 20)
# harmonizing from (47, 37), delta: (29, 17), dir: 1
# adding (47, 37)
# harmonizing from (37, 44), delta: (5, 1), dir: -1
# adding (37, 44)
# adding (32, 43)
# adding (27, 42)
# adding (22, 41)
# adding (17, 40)
# adding (12, 39)
# adding (7, 38)
# adding (2, 37)
# harmonizing from (42, 45), delta: (5, 1), dir: 1
# adding (42, 45)
# adding (47, 46)
# harmonizing from (37, 44), delta: (10, -7), dir: -1
# adding (37, 44)
# harmonizing from (47, 37), delta: (10, -7), dir: 1
# adding (47, 37)
# harmonizing from (42, 45), delta: (5, -8), dir: -1
# adding (42, 45)
# harmonizing from (47, 37), delta: (5, -8), dir: 1
# adding (47, 37)
# harmonizing from (18, 28), delta: (13, -8), dir: -1
# adding (18, 28)
# adding (5, 36)
# harmonizing from (31, 20), delta: (13, -8), dir: 1
# adding (31, 20)
# adding (44, 12)
# harmonizing from (18, 28), delta: (19, 11), dir: -1
# adding (18, 28)
# harmonizing from (37, 39), delta: (19, 11), dir: 1
# adding (37, 39)
# harmonizing from (18, 28), delta: (20, 19), dir: -1
# adding (18, 28)
# harmonizing from (38, 47), delta: (20, 19), dir: 1
# adding (38, 47)
# harmonizing from (31, 20), delta: (6, 19), dir: -1
# adding (31, 20)
# adding (25, 1)
# harmonizing from (37, 39), delta: (6, 19), dir: 1
# adding (37, 39)
# harmonizing from (31, 20), delta: (7, 27), dir: -1
# adding (31, 20)
# harmonizing from (38, 47), delta: (7, 27), dir: 1
# adding (38, 47)
# harmonizing from (37, 39), delta: (1, 8), dir: -1
# adding (37, 39)
# adding (36, 31)
# adding (35, 23)
# adding (34, 15)
# adding (33, 7)
# harmonizing from (38, 47), delta: (1, 8), dir: 1
# adding (38, 47)
# harmonizing from (19, 14), delta: (1, -7), dir: -1
# adding (19, 14)
# adding (18, 21)
# adding (17, 28)
# adding (16, 35)
# adding (15, 42)
# adding (14, 49)
# harmonizing from (20, 7), delta: (1, -7), dir: 1
# adding (20, 7)
# adding (21, 0)
# harmonizing from (19, 14), delta: (2, 1), dir: -1
# adding (19, 14)
# adding (17, 13)
# adding (15, 12)
# adding (13, 11)
# adding (11, 10)
# adding (9, 9)
# adding (7, 8)
# adding (5, 7)
# adding (3, 6)
# adding (1, 5)
# harmonizing from (21, 15), delta: (2, 1), dir: 1
# adding (21, 15)
# adding (23, 16)
# adding (25, 17)
# adding (27, 18)
# adding (29, 19)
# adding (31, 20)
# adding (33, 21)
# adding (35, 22)
# adding (37, 23)
# adding (39, 24)
# adding (41, 25)
# adding (43, 26)
# adding (45, 27)
# adding (47, 28)
# adding (49, 29)
# harmonizing from (19, 14), delta: (9, 2), dir: -1
# adding (19, 14)
# adding (10, 12)
# adding (1, 10)
# harmonizing from (28, 16), delta: (9, 2), dir: 1
# adding (28, 16)
# adding (37, 18)
# adding (46, 20)
# harmonizing from (20, 7), delta: (1, 8), dir: -1
# adding (20, 7)
# harmonizing from (21, 15), delta: (1, 8), dir: 1
# adding (21, 15)
# adding (22, 23)
# adding (23, 31)
# adding (24, 39)
# adding (25, 47)
# harmonizing from (20, 7), delta: (8, 9), dir: -1
# adding (20, 7)
# harmonizing from (28, 16), delta: (8, 9), dir: 1
# adding (28, 16)
# adding (36, 25)
# adding (44, 34)
# harmonizing from (21, 15), delta: (7, 1), dir: -1
# adding (21, 15)
# adding (14, 14)
# adding (7, 13)
# adding (0, 12)
# harmonizing from (28, 16), delta: (7, 1), dir: 1
# adding (28, 16)
# adding (35, 17)
# adding (42, 18)
# adding (49, 19)
# harmonizing from (19, 25), delta: (2, -1), dir: -1
# adding (19, 25)
# adding (17, 26)
# adding (15, 27)
# adding (13, 28)
# adding (11, 29)
# adding (9, 30)
# adding (7, 31)
# adding (5, 32)
# adding (3, 33)
# adding (1, 34)
# harmonizing from (21, 24), delta: (2, -1), dir: 1
# adding (21, 24)
# adding (23, 23)
# adding (25, 22)
# adding (27, 21)
# adding (29, 20)
# adding (31, 19)
# adding (33, 18)
# adding (35, 17)
# adding (37, 16)
# adding (39, 15)
# adding (41, 14)
# adding (43, 13)
# adding (45, 12)
# adding (47, 11)
# adding (49, 10)
# harmonizing from (19, 25), delta: (5, -3), dir: -1
# adding (19, 25)
# adding (14, 28)
# adding (9, 31)
# adding (4, 34)
# harmonizing from (24, 22), delta: (5, -3), dir: 1
# adding (24, 22)
# adding (29, 19)
# adding (34, 16)
# adding (39, 13)
# adding (44, 10)
# adding (49, 7)
# harmonizing from (19, 25), delta: (7, -12), dir: -1
# adding (19, 25)
# adding (12, 37)
# adding (5, 49)
# harmonizing from (26, 13), delta: (7, -12), dir: 1
# adding (26, 13)
# adding (33, 1)
# harmonizing from (21, 24), delta: (3, -2), dir: -1
# adding (21, 24)
# adding (18, 26)
# adding (15, 28)
# adding (12, 30)
# adding (9, 32)
# adding (6, 34)
# adding (3, 36)
# adding (0, 38)
# harmonizing from (24, 22), delta: (3, -2), dir: 1
# adding (24, 22)
# adding (27, 20)
# adding (30, 18)
# adding (33, 16)
# adding (36, 14)
# adding (39, 12)
# adding (42, 10)
# adding (45, 8)
# adding (48, 6)
# harmonizing from (21, 24), delta: (5, -11), dir: -1
# adding (21, 24)
# adding (16, 35)
# adding (11, 46)
# harmonizing from (26, 13), delta: (5, -11), dir: 1
# adding (26, 13)
# adding (31, 2)
# harmonizing from (24, 22), delta: (2, -9), dir: -1
# adding (24, 22)
# adding (22, 31)
# adding (20, 40)
# adding (18, 49)
# harmonizing from (26, 13), delta: (2, -9), dir: 1
# adding (26, 13)
# adding (28, 4)
# harmonizing from (21, 34), delta: (1, 10), dir: -1
# adding (21, 34)
# adding (20, 24)
# adding (19, 14)
# adding (18, 4)
# harmonizing from (22, 44), delta: (1, 10), dir: 1
# adding (22, 44)
# harmonizing from (21, 34), delta: (4, 9), dir: -1
# adding (21, 34)
# adding (17, 25)
# adding (13, 16)
# adding (9, 7)
# harmonizing from (25, 43), delta: (4, 9), dir: 1
# adding (25, 43)
# harmonizing from (21, 34), delta: (5, 7), dir: -1
# adding (21, 34)
# adding (16, 27)
# adding (11, 20)
# adding (6, 13)
# adding (1, 6)
# harmonizing from (26, 41), delta: (5, 7), dir: 1
# adding (26, 41)
# adding (31, 48)
# harmonizing from (22, 44), delta: (3, -1), dir: -1
# adding (22, 44)
# adding (19, 45)
# adding (16, 46)
# adding (13, 47)
# adding (10, 48)
# adding (7, 49)
# harmonizing from (25, 43), delta: (3, -1), dir: 1
# adding (25, 43)
# adding (28, 42)
# adding (31, 41)
# adding (34, 40)
# adding (37, 39)
# adding (40, 38)
# adding (43, 37)
# adding (46, 36)
# adding (49, 35)
# harmonizing from (22, 44), delta: (4, -3), dir: -1
# adding (22, 44)
# adding (18, 47)
# harmonizing from (26, 41), delta: (4, -3), dir: 1
# adding (26, 41)
# adding (30, 38)
# adding (34, 35)
# adding (38, 32)
# adding (42, 29)
# adding (46, 26)
# harmonizing from (25, 43), delta: (1, -2), dir: -1
# adding (25, 43)
# adding (24, 45)
# adding (23, 47)
# adding (22, 49)
# harmonizing from (26, 41), delta: (1, -2), dir: 1
# adding (26, 41)
# adding (27, 39)
# adding (28, 37)
# adding (29, 35)
# adding (30, 33)
# adding (31, 31)
# adding (32, 29)
# adding (33, 27)
# adding (34, 25)
# adding (35, 23)
# adding (36, 21)
# adding (37, 19)
# adding (38, 17)
# adding (39, 15)
# adding (40, 13)
# adding (41, 11)
# adding (42, 9)
# adding (43, 7)
# adding (44, 5)
# adding (45, 3)
# adding (46, 1)
# harmonizing from (23, 35), delta: (10, -3), dir: -1
# adding (23, 35)
# adding (13, 38)
# adding (3, 41)
# harmonizing from (33, 32), delta: (10, -3), dir: 1
# adding (33, 32)
# adding (43, 29)
# harmonizing from (23, 35), delta: (13, -4), dir: -1
# adding (23, 35)
# adding (10, 39)
# harmonizing from (36, 31), delta: (13, -4), dir: 1
# adding (36, 31)
# adding (49, 27)
# harmonizing from (33, 32), delta: (3, -1), dir: -1
# adding (33, 32)
# adding (30, 33)
# adding (27, 34)
# adding (24, 35)
# adding (21, 36)
# adding (18, 37)
# adding (15, 38)
# adding (12, 39)
# adding (9, 40)
# adding (6, 41)
# adding (3, 42)
# adding (0, 43)
# harmonizing from (36, 31), delta: (3, -1), dir: 1
# adding (36, 31)
# adding (39, 30)
# adding (42, 29)
# adding (45, 28)
# adding (48, 27)
# harmonizing from (24, 4), delta: (1, 16), dir: -1
# adding (24, 4)
# harmonizing from (25, 20), delta: (1, 16), dir: 1
# adding (25, 20)
# adding (26, 36)
# harmonizing from (24, 4), delta: (2, 3), dir: -1
# adding (24, 4)
# adding (22, 1)
# harmonizing from (26, 7), delta: (2, 3), dir: 1
# adding (26, 7)
# adding (28, 10)
# adding (30, 13)
# adding (32, 16)
# adding (34, 19)
# adding (36, 22)
# adding (38, 25)
# adding (40, 28)
# adding (42, 31)
# adding (44, 34)
# adding (46, 37)
# adding (48, 40)
# harmonizing from (24, 4), delta: (11, -1), dir: -1
# adding (24, 4)
# adding (13, 5)
# adding (2, 6)
# harmonizing from (35, 3), delta: (11, -1), dir: 1
# adding (35, 3)
# adding (46, 2)
# harmonizing from (25, 20), delta: (1, -13), dir: -1
# adding (25, 20)
# adding (24, 33)
# adding (23, 46)
# harmonizing from (26, 7), delta: (1, -13), dir: 1
# adding (26, 7)
# harmonizing from (25, 20), delta: (10, -17), dir: -1
# adding (25, 20)
# adding (15, 37)
# harmonizing from (35, 3), delta: (10, -17), dir: 1
# adding (35, 3)
# harmonizing from (26, 7), delta: (9, -4), dir: -1
# adding (26, 7)
# adding (17, 11)
# adding (8, 15)
# harmonizing from (35, 3), delta: (9, -4), dir: 1
# adding (35, 3)
# harmonizing from (25, 0), delta: (3, 11), dir: -1
# adding (25, 0)
# harmonizing from (28, 11), delta: (3, 11), dir: 1
# adding (28, 11)
# adding (31, 22)
# adding (34, 33)
# adding (37, 44)
# harmonizing from (25, 0), delta: (4, 13), dir: -1
# adding (25, 0)
# harmonizing from (29, 13), delta: (4, 13), dir: 1
# adding (29, 13)
# adding (33, 26)
# adding (37, 39)
# harmonizing from (25, 0), delta: (13, 12), dir: -1
# adding (25, 0)
# harmonizing from (38, 12), delta: (13, 12), dir: 1
# adding (38, 12)
# harmonizing from (28, 11), delta: (1, 2), dir: -1
# adding (28, 11)
# adding (27, 9)
# adding (26, 7)
# adding (25, 5)
# adding (24, 3)
# adding (23, 1)
# harmonizing from (29, 13), delta: (1, 2), dir: 1
# adding (29, 13)
# adding (30, 15)
# adding (31, 17)
# adding (32, 19)
# adding (33, 21)
# adding (34, 23)
# adding (35, 25)
# adding (36, 27)
# adding (37, 29)
# adding (38, 31)
# adding (39, 33)
# adding (40, 35)
# adding (41, 37)
# adding (42, 39)
# adding (43, 41)
# adding (44, 43)
# adding (45, 45)
# adding (46, 47)
# adding (47, 49)
# harmonizing from (28, 11), delta: (10, 1), dir: -1
# adding (28, 11)
# adding (18, 10)
# adding (8, 9)
# harmonizing from (38, 12), delta: (10, 1), dir: 1
# adding (38, 12)
# adding (48, 13)
# harmonizing from (29, 13), delta: (9, -1), dir: -1
# adding (29, 13)
# adding (20, 14)
# adding (11, 15)
# adding (2, 16)
# harmonizing from (38, 12), delta: (9, -1), dir: 1
# adding (38, 12)
# adding (47, 11)
# harmonizing from (26, 18), delta: (8, -1), dir: -1
# adding (26, 18)
# adding (18, 19)
# adding (10, 20)
# adding (2, 21)
# harmonizing from (34, 17), delta: (8, -1), dir: 1
# adding (34, 17)
# adding (42, 16)
# harmonizing from (26, 18), delta: (9, 7), dir: -1
# adding (26, 18)
# adding (17, 11)
# adding (8, 4)
# harmonizing from (35, 25), delta: (9, 7), dir: 1
# adding (35, 25)
# adding (44, 32)
# harmonizing from (26, 18), delta: (11, 4), dir: -1
# adding (26, 18)
# adding (15, 14)
# adding (4, 10)
# harmonizing from (37, 22), delta: (11, 4), dir: 1
# adding (37, 22)
# adding (48, 26)
# harmonizing from (34, 17), delta: (1, 8), dir: -1
# adding (34, 17)
# adding (33, 9)
# adding (32, 1)
# harmonizing from (35, 25), delta: (1, 8), dir: 1
# adding (35, 25)
# adding (36, 33)
# adding (37, 41)
# adding (38, 49)
# harmonizing from (34, 17), delta: (3, 5), dir: -1
# adding (34, 17)
# adding (31, 12)
# adding (28, 7)
# adding (25, 2)
# harmonizing from (37, 22), delta: (3, 5), dir: 1
# adding (37, 22)
# adding (40, 27)
# adding (43, 32)
# adding (46, 37)
# adding (49, 42)
# harmonizing from (35, 25), delta: (2, -3), dir: -1
# adding (35, 25)
# adding (33, 28)
# adding (31, 31)
# adding (29, 34)
# adding (27, 37)
# adding (25, 40)
# adding (23, 43)
# adding (21, 46)
# adding (19, 49)
# harmonizing from (37, 22), delta: (2, -3), dir: 1
# adding (37, 22)
# adding (39, 19)
# adding (41, 16)
# adding (43, 13)
# adding (45, 10)
# adding (47, 7)
# adding (49, 4)
# harmonizing from (27, 13), delta: (2, -7), dir: -1
# adding (27, 13)
# adding (25, 20)
# adding (23, 27)
# adding (21, 34)
# adding (19, 41)
# adding (17, 48)
# harmonizing from (29, 6), delta: (2, -7), dir: 1
# adding (29, 6)
# harmonizing from (27, 13), delta: (7, -13), dir: -1
# adding (27, 13)
# adding (20, 26)
# adding (13, 39)
# harmonizing from (34, 0), delta: (7, -13), dir: 1
# adding (34, 0)
# harmonizing from (27, 13), delta: (13, -8), dir: -1
# adding (27, 13)
# adding (14, 21)
# adding (1, 29)
# harmonizing from (40, 5), delta: (13, -8), dir: 1
# adding (40, 5)
# harmonizing from (29, 6), delta: (5, -6), dir: -1
# adding (29, 6)
# adding (24, 12)
# adding (19, 18)
# adding (14, 24)
# adding (9, 30)
# adding (4, 36)
# harmonizing from (34, 0), delta: (5, -6), dir: 1
# adding (34, 0)
# harmonizing from (29, 6), delta: (11, -1), dir: -1
# adding (29, 6)
# adding (18, 7)
# adding (7, 8)
# harmonizing from (40, 5), delta: (11, -1), dir: 1
# adding (40, 5)
# harmonizing from (34, 0), delta: (6, 5), dir: -1
# adding (34, 0)
# harmonizing from (40, 5), delta: (6, 5), dir: 1
# adding (40, 5)
# adding (46, 10)
# harmonizing from (27, 34), delta: (5, -18), dir: -1
# adding (27, 34)
# harmonizing from (32, 16), delta: (5, -18), dir: 1
# adding (32, 16)
# harmonizing from (27, 34), delta: (11, -25), dir: -1
# adding (27, 34)
# harmonizing from (38, 9), delta: (11, -25), dir: 1
# adding (38, 9)
# harmonizing from (27, 34), delta: (14, -29), dir: -1
# adding (27, 34)
# harmonizing from (41, 5), delta: (14, -29), dir: 1
# adding (41, 5)
# harmonizing from (32, 16), delta: (6, -7), dir: -1
# adding (32, 16)
# adding (26, 23)
# adding (20, 30)
# adding (14, 37)
# adding (8, 44)
# harmonizing from (38, 9), delta: (6, -7), dir: 1
# adding (38, 9)
# adding (44, 2)
# harmonizing from (32, 16), delta: (9, -11), dir: -1
# adding (32, 16)
# adding (23, 27)
# adding (14, 38)
# adding (5, 49)
# harmonizing from (41, 5), delta: (9, -11), dir: 1
# adding (41, 5)
# harmonizing from (38, 9), delta: (3, -4), dir: -1
# adding (38, 9)
# adding (35, 13)
# adding (32, 17)
# adding (29, 21)
# adding (26, 25)
# adding (23, 29)
# adding (20, 33)
# adding (17, 37)
# adding (14, 41)
# adding (11, 45)
# adding (8, 49)
# harmonizing from (41, 5), delta: (3, -4), dir: 1
# adding (41, 5)
# adding (44, 1)
# harmonizing from (30, 1), delta: (11, 9), dir: -1
# adding (30, 1)
# harmonizing from (41, 10), delta: (11, 9), dir: 1
# adding (41, 10)
# harmonizing from (30, 1), delta: (12, 25), dir: -1
# adding (30, 1)
# harmonizing from (42, 26), delta: (12, 25), dir: 1
# adding (42, 26)
# harmonizing from (30, 1), delta: (19, 12), dir: -1
# adding (30, 1)
# harmonizing from (49, 13), delta: (19, 12), dir: 1
# adding (49, 13)
# harmonizing from (41, 10), delta: (1, 16), dir: -1
# adding (41, 10)
# harmonizing from (42, 26), delta: (1, 16), dir: 1
# adding (42, 26)
# adding (43, 42)
# harmonizing from (41, 10), delta: (8, 3), dir: -1
# adding (41, 10)
# adding (33, 7)
# adding (25, 4)
# adding (17, 1)
# harmonizing from (49, 13), delta: (8, 3), dir: 1
# adding (49, 13)
# harmonizing from (42, 26), delta: (7, -13), dir: -1
# adding (42, 26)
# adding (35, 39)
# harmonizing from (49, 13), delta: (7, -13), dir: 1
# adding (49, 13)
# harmonizing from (33, 3), delta: (1, 7), dir: -1
# adding (33, 3)
# harmonizing from (34, 10), delta: (1, 7), dir: 1
# adding (34, 10)
# adding (35, 17)
# adding (36, 24)
# adding (37, 31)
# adding (38, 38)
# adding (39, 45)
# harmonizing from (33, 3), delta: (8, -1), dir: -1
# adding (33, 3)
# adding (25, 4)
# adding (17, 5)
# adding (9, 6)
# adding (1, 7)
# harmonizing from (41, 2), delta: (8, -1), dir: 1
# adding (41, 2)
# adding (49, 1)
# harmonizing from (33, 3), delta: (11, 10), dir: -1
# adding (33, 3)
# harmonizing from (44, 13), delta: (11, 10), dir: 1
# adding (44, 13)
# harmonizing from (34, 10), delta: (7, -8), dir: -1
# adding (34, 10)
# adding (27, 18)
# adding (20, 26)
# adding (13, 34)
# adding (6, 42)
# harmonizing from (41, 2), delta: (7, -8), dir: 1
# adding (41, 2)
# harmonizing from (34, 10), delta: (10, 3), dir: -1
# adding (34, 10)
# adding (24, 7)
# adding (14, 4)
# adding (4, 1)
# harmonizing from (44, 13), delta: (10, 3), dir: 1
# adding (44, 13)
# harmonizing from (41, 2), delta: (3, 11), dir: -1
# adding (41, 2)
# harmonizing from (44, 13), delta: (3, 11), dir: 1
# adding (44, 13)
# adding (47, 24)
# harmonizing from (34, 5), delta: (1, 3), dir: -1
# adding (34, 5)
# adding (33, 2)
# harmonizing from (35, 8), delta: (1, 3), dir: 1
# adding (35, 8)
# adding (36, 11)
# adding (37, 14)
# adding (38, 17)
# adding (39, 20)
# adding (40, 23)
# adding (41, 26)
# adding (42, 29)
# adding (43, 32)
# adding (44, 35)
# adding (45, 38)
# adding (46, 41)
# adding (47, 44)
# adding (48, 47)
# harmonizing from (34, 5), delta: (11, 20), dir: -1
# adding (34, 5)
# harmonizing from (45, 25), delta: (11, 20), dir: 1
# adding (45, 25)
# harmonizing from (35, 8), delta: (10, 17), dir: -1
# adding (35, 8)
# harmonizing from (45, 25), delta: (10, 17), dir: 1
# adding (45, 25)
# harmonizing from (34, 37), delta: (3, -5), dir: -1
# adding (34, 37)
# adding (31, 42)
# adding (28, 47)
# harmonizing from (37, 32), delta: (3, -5), dir: 1
# adding (37, 32)
# adding (40, 27)
# adding (43, 22)
# adding (46, 17)
# adding (49, 12)
# harmonizing from (34, 37), delta: (4, -7), dir: -1
# adding (34, 37)
# adding (30, 44)
# harmonizing from (38, 30), delta: (4, -7), dir: 1
# adding (38, 30)
# adding (42, 23)
# adding (46, 16)
# harmonizing from (34, 37), delta: (11, -20), dir: -1
# adding (34, 37)
# harmonizing from (45, 17), delta: (11, -20), dir: 1
# adding (45, 17)
# harmonizing from (37, 32), delta: (1, -2), dir: -1
# adding (37, 32)
# adding (36, 34)
# adding (35, 36)
# adding (34, 38)
# adding (33, 40)
# adding (32, 42)
# adding (31, 44)
# adding (30, 46)
# adding (29, 48)
# harmonizing from (38, 30), delta: (1, -2), dir: 1
# adding (38, 30)
# adding (39, 28)
# adding (40, 26)
# adding (41, 24)
# adding (42, 22)
# adding (43, 20)
# adding (44, 18)
# adding (45, 16)
# adding (46, 14)
# adding (47, 12)
# adding (48, 10)
# adding (49, 8)
# harmonizing from (37, 32), delta: (8, -15), dir: -1
# adding (37, 32)
# adding (29, 47)
# harmonizing from (45, 17), delta: (8, -15), dir: 1
# adding (45, 17)
# harmonizing from (38, 30), delta: (7, -13), dir: -1
# adding (38, 30)
# adding (31, 43)
# harmonizing from (45, 17), delta: (7, -13), dir: 1
# adding (45, 17)
# harmonizing from (36, 23), delta: (4, -3), dir: -1
# adding (36, 23)
# adding (32, 26)
# adding (28, 29)
# adding (24, 32)
# adding (20, 35)
# adding (16, 38)
# adding (12, 41)
# adding (8, 44)
# adding (4, 47)
# harmonizing from (40, 20), delta: (4, -3), dir: 1
# adding (40, 20)
# adding (44, 17)
# adding (48, 14)
# harmonizing from (36, 23), delta: (9, -2), dir: -1
# adding (36, 23)
# adding (27, 25)
# adding (18, 27)
# adding (9, 29)
# adding (0, 31)
# harmonizing from (45, 21), delta: (9, -2), dir: 1
# adding (45, 21)
# harmonizing from (36, 23), delta: (13, -1), dir: -1
# adding (36, 23)
# adding (23, 24)
# adding (10, 25)
# harmonizing from (49, 22), delta: (13, -1), dir: 1
# adding (49, 22)
# harmonizing from (40, 20), delta: (5, 1), dir: -1
# adding (40, 20)
# adding (35, 19)
# adding (30, 18)
# adding (25, 17)
# adding (20, 16)
# adding (15, 15)
# adding (10, 14)
# adding (5, 13)
# adding (0, 12)
# harmonizing from (45, 21), delta: (5, 1), dir: 1
# adding (45, 21)
# harmonizing from (40, 20), delta: (9, 2), dir: -1
# adding (40, 20)
# adding (31, 18)
# adding (22, 16)
# adding (13, 14)
# adding (4, 12)
# harmonizing from (49, 22), delta: (9, 2), dir: 1
# adding (49, 22)
# harmonizing from (45, 21), delta: (4, 1), dir: -1
# adding (45, 21)
# adding (41, 20)
# adding (37, 19)
# adding (33, 18)
# adding (29, 17)
# adding (25, 16)
# adding (21, 15)
# adding (17, 14)
# adding (13, 13)
# adding (9, 12)
# adding (5, 11)
# adding (1, 10)
# harmonizing from (49, 22), delta: (4, 1), dir: 1
# adding (49, 22)
# harmonizing from (36, 42), delta: (8, 7), dir: -1
# adding (36, 42)
# adding (28, 35)
# adding (20, 28)
# adding (12, 21)
# adding (4, 14)
# harmonizing from (44, 49), delta: (8, 7), dir: 1
# adding (44, 49)
# harmonizing from (36, 42), delta: (9, 5), dir: -1
# adding (36, 42)
# adding (27, 37)
# adding (18, 32)
# adding (9, 27)
# adding (0, 22)
# harmonizing from (45, 47), delta: (9, 5), dir: 1
# adding (45, 47)
# harmonizing from (36, 42), delta: (13, 4), dir: -1
# adding (36, 42)
# adding (23, 38)
# adding (10, 34)
# harmonizing from (49, 46), delta: (13, 4), dir: 1
# adding (49, 46)
# harmonizing from (44, 49), delta: (1, -2), dir: -1
# adding (44, 49)
# harmonizing from (45, 47), delta: (1, -2), dir: 1
# adding (45, 47)
# adding (46, 45)
# adding (47, 43)
# adding (48, 41)
# adding (49, 39)
# harmonizing from (44, 49), delta: (5, -3), dir: -1
# adding (44, 49)
# harmonizing from (49, 46), delta: (5, -3), dir: 1
# adding (49, 46)
# harmonizing from (45, 47), delta: (4, -1), dir: -1
# adding (45, 47)
# adding (41, 48)
# adding (37, 49)
# harmonizing from (49, 46), delta: (4, -1), dir: 1
# adding (49, 46)
# harmonizing from (39, 35), delta: (3, -29), dir: -1
# adding (39, 35)
# harmonizing from (42, 6), delta: (3, -29), dir: 1
# adding (42, 6)
# harmonizing from (39, 35), delta: (4, 1), dir: -1
# adding (39, 35)
# adding (35, 34)
# adding (31, 33)
# adding (27, 32)
# adding (23, 31)
# adding (19, 30)
# adding (15, 29)
# adding (11, 28)
# adding (7, 27)
# adding (3, 26)
# harmonizing from (43, 36), delta: (4, 1), dir: 1
# adding (43, 36)
# adding (47, 37)
# harmonizing from (42, 6), delta: (1, 30), dir: -1
# adding (42, 6)
# harmonizing from (43, 36), delta: (1, 30), dir: 1
# adding (43, 36)
# harmonizing from (42, 7), delta: (1, -6), dir: -1
# adding (42, 7)
# adding (41, 13)
# adding (40, 19)
# adding (39, 25)
# adding (38, 31)
# adding (37, 37)
# adding (36, 43)
# adding (35, 49)
# harmonizing from (43, 1), delta: (1, -6), dir: 1
# adding (43, 1)
# harmonizing from (42, 7), delta: (2, -5), dir: -1
# adding (42, 7)
# adding (40, 12)
# adding (38, 17)
# adding (36, 22)
# adding (34, 27)
# adding (32, 32)
# adding (30, 37)
# adding (28, 42)
# adding (26, 47)
# harmonizing from (44, 2), delta: (2, -5), dir: 1
# adding (44, 2)
# harmonizing from (42, 7), delta: (3, -1), dir: -1
# adding (42, 7)
# adding (39, 8)
# adding (36, 9)
# adding (33, 10)
# adding (30, 11)
# adding (27, 12)
# adding (24, 13)
# adding (21, 14)
# adding (18, 15)
# adding (15, 16)
# adding (12, 17)
# adding (9, 18)
# adding (6, 19)
# adding (3, 20)
# adding (0, 21)
# harmonizing from (45, 6), delta: (3, -1), dir: 1
# adding (45, 6)
# adding (48, 5)
# harmonizing from (43, 1), delta: (1, 1), dir: -1
# adding (43, 1)
# adding (42, 0)
# harmonizing from (44, 2), delta: (1, 1), dir: 1
# adding (44, 2)
# adding (45, 3)
# adding (46, 4)
# adding (47, 5)
# adding (48, 6)
# adding (49, 7)
# harmonizing from (43, 1), delta: (2, 5), dir: -1
# adding (43, 1)
# harmonizing from (45, 6), delta: (2, 5), dir: 1
# adding (45, 6)
# adding (47, 11)
# adding (49, 16)
# harmonizing from (44, 2), delta: (1, 4), dir: -1
# adding (44, 2)
# harmonizing from (45, 6), delta: (1, 4), dir: 1
# adding (45, 6)
# adding (46, 10)
# adding (47, 14)
# adding (48, 18)
# adding (49, 22)
# harmonizing from (42, 39), delta: (2, 5), dir: -1
# adding (42, 39)
# adding (40, 34)
# adding (38, 29)
# adding (36, 24)
# adding (34, 19)
# adding (32, 14)
# adding (30, 9)
# adding (28, 4)
# harmonizing from (44, 44), delta: (2, 5), dir: 1
# adding (44, 44)
# adding (46, 49)
# harmonizing from (42, 39), delta: (3, -11), dir: -1
# adding (42, 39)
# harmonizing from (45, 28), delta: (3, -11), dir: 1
# adding (45, 28)
# adding (48, 17)
# harmonizing from (42, 39), delta: (7, -6), dir: -1
# adding (42, 39)
# adding (35, 45)
# harmonizing from (49, 33), delta: (7, -6), dir: 1
# adding (49, 33)
# harmonizing from (44, 44), delta: (1, -16), dir: -1
# adding (44, 44)
# harmonizing from (45, 28), delta: (1, -16), dir: 1
# adding (45, 28)
# adding (46, 12)
# harmonizing from (44, 44), delta: (5, -11), dir: -1
# adding (44, 44)
# harmonizing from (49, 33), delta: (5, -11), dir: 1
# adding (49, 33)
# harmonizing from (45, 28), delta: (4, 5), dir: -1
# adding (45, 28)
# adding (41, 23)
# adding (37, 18)
# adding (33, 13)
# adding (29, 8)
# adding (25, 3)
# harmonizing from (49, 33), delta: (4, 5), dir: 1
# adding (49, 33)
# harmonizing from (44, 27), delta: (1, -4), dir: -1
# adding (44, 27)
# adding (43, 31)
# adding (42, 35)
# adding (41, 39)
# adding (40, 43)
# adding (39, 47)
# harmonizing from (45, 23), delta: (1, -4), dir: 1
# adding (45, 23)
# adding (46, 19)
# adding (47, 15)
# adding (48, 11)
# adding (49, 7)
# harmonizing from (44, 27), delta: (3, -13), dir: -1
# adding (44, 27)
# adding (41, 40)
# harmonizing from (47, 14), delta: (3, -13), dir: 1
# adding (47, 14)
# harmonizing from (44, 27), delta: (4, -5), dir: -1
# adding (44, 27)
# adding (40, 32)
# adding (36, 37)
# adding (32, 42)
# adding (28, 47)
# harmonizing from (48, 22), delta: (4, -5), dir: 1
# adding (48, 22)
# harmonizing from (45, 23), delta: (2, -9), dir: -1
# adding (45, 23)
# adding (43, 32)
# adding (41, 41)
# harmonizing from (47, 14), delta: (2, -9), dir: 1
# adding (47, 14)
# adding (49, 5)
# harmonizing from (45, 23), delta: (3, -1), dir: -1
# adding (45, 23)
# adding (42, 24)
# adding (39, 25)
# adding (36, 26)
# adding (33, 27)
# adding (30, 28)
# adding (27, 29)
# adding (24, 30)
# adding (21, 31)
# adding (18, 32)
# adding (15, 33)
# adding (12, 34)
# adding (9, 35)
# adding (6, 36)
# adding (3, 37)
# adding (0, 38)
# harmonizing from (48, 22), delta: (3, -1), dir: 1
# adding (48, 22)
# harmonizing from (47, 14), delta: (1, 8), dir: -1
# adding (47, 14)
# adding (46, 6)
# harmonizing from (48, 22), delta: (1, 8), dir: 1
# adding (48, 22)
# adding (49, 30)
# harmonizing from (45, 18), delta: (3, -10), dir: -1
# adding (45, 18)
# adding (42, 28)
# adding (39, 38)
# adding (36, 48)
# harmonizing from (48, 8), delta: (3, -10), dir: 1
# adding (48, 8)
# harmonizing from (45, 18), delta: (4, -7), dir: -1
# adding (45, 18)
# adding (41, 25)
# adding (37, 32)
# adding (33, 39)
# adding (29, 46)
# harmonizing from (49, 11), delta: (4, -7), dir: 1
# adding (49, 11)
# harmonizing from (48, 8), delta: (1, 3), dir: -1
# adding (48, 8)
# adding (47, 5)
# adding (46, 2)
# harmonizing from (49, 11), delta: (1, 3), dir: 1
# adding (49, 11)
# {(26, 30),
#  (18, 26),
#  (18, 35),
#  (7, 35),
#  (27, 13),
#  (29, 32),
#  (8, 9),
#  (30, 9),
#  (29, 41),
#  (30, 18),
#  (21, 37),
#  (19, 18),
#  (6, 48),
#  (11, 14),
#  (21, 46),
#  (41, 24),
#  (33, 20),
#  (33, 29),
#  (4, 2),
#  (45, 3),
#  (44, 47),
#  (34, 12),
#  (45, 12),
#  (25, 43),
#  (3, 6),
#  (45, 21),
#  (14, 15),
#  (3, 15),
#  (3, 24),
#  (14, 24),
#  (22, 37),
#  (46, 4),
#  (14, 33),
#  (3, 33),
#  (22, 46),
#  (3, 42),
#  (26, 7),
#  (38, 9),
#  (7, 3),
#  (49, 18),
#  (15, 16),
#  (47, 48),
#  (36, 48),
#  (26, 25),
#  (18, 21),
#  (48, 22),
#  (40, 27),
#  (48, 40),
#  (8, 4),
#  (6, 34),
#  (30, 13),
#  (21, 32),
#  (11, 9),
#  (41, 10),
#  (10, 22),
#  (33, 24),
#  (41, 37),
#  (25, 20),
#  (25, 29),
#  (45, 7),
#  (34, 7),
#  (2, 36),
#  (34, 16),
#  (45, 16),
#  (25, 47),
#  (3, 10),
#  (34, 25),
#  (22, 23),
#  (45, 25),
#  (3, 19),
#  (14, 28),
#  (3, 37),
#  (26, 2),
#  (49, 4),
#  (14, 37),
#  (47, 34),
#  (36, 34),
#  (7, 7),
#  (18, 7),
#  (26, 20),
#  (47, 43),
#  (36, 43),
#  (7, 16),
#  (48, 17),
#  (28, 48),
#  (29, 13),
#  (17, 48),
#  (48, 26),
#  (40, 31),
#  (41, 5),
#  (21, 36),
#  (44, 1),
#  (33, 1),
#  (41, 14),
#  (21, 45),
#  (44, 10),
#  (33, 10),
#  (41, 23),
#  (44, 19),
#  (33, 19),
#  (41, 32),
#  (33, 28),
#  (44, 37),
#  (10, 44),
#  (22, 9),
#  (2, 40),
#  (25, 42),
#  (32, 41),
#  (14, 5),
#  (43, 41),
#  (14, 14),
#  (37, 16),
#  (15, 6),
#  (17, 25),
#  (47, 38),
#  (36, 47),
#  (9, 30),
#  (28, 43),
#  (29, 8),
#  (29, 17),
#  (48, 30),
#  (40, 26),
#  (48, 39),
#  (29, 35),
#  (40, 35),
#  (21, 31),
#  (40, 44),
#  (6, 42),
#  (44, 5),
#  (25, 1),
#  (44, 14),
#  (10, 12),
#  (2, 8),
#  (2, 17),
#  (10, 30),
#  (10, 39),
#  (22, 4),
#  (45, 6),
#  (3, 0),
#  (43, 36),
#  (22, 13),
#  (24, 32),
#  (24, 41),
#  (13, 41),
#  (35, 41),
#  (47, 15),
#  (16, 46),
#  (36, 24),
#  (47, 24),
#  (36, 33),
#  (28, 29),
#  (36, 42),
#  (5, 36),
#  (5, 45),
#  (17, 47),
#  (28, 47),
#  (9, 43),
#  (48, 25),
#  (40, 12),
#  (29, 21),
#  (6, 19),
#  (21, 26),
#  (33, 0),
#  (41, 13),
#  (33, 9),
#  (25, 5),
#  (10, 16),
#  (33, 18),
#  (44, 18),
#  (2, 12),
#  (31, 48),
#  (10, 25),
#  (2, 21),
#  (43, 22),
#  (4, 49),
#  (43, 31),
#  (32, 40),
#  (14, 4),
#  (1, 34),
#  (35, 36),
#  (43, 49),
#  (13, 45),
#  (35, 45),
#  (24, 45),
#  (17, 6),
#  (36, 19),
#  (47, 28),
#  (17, 24),
#  (47, 37),
#  (36, 37),
#  (47, 46),
#  (9, 29),
#  (48, 11),
#  (28, 42),
#  (6, 5),
#  (5, 49),
#  (21, 12),
#  (21, 21),
#  (39, 38),
#  (25, 0),
#  (39, 47),
#  (25, 9),
#  (20, 43),
#  (31, 43),
#  (12, 39),
#  (2, 16),
#  (32, 17),
#  (13, 13),
#  (24, 13),
#  (43, 26),
#  (32, 26),
#  (13, 22),
#  (35, 22),
#  (24, 22),
#  (35, 31),
#  (1, 29),
#  (32, 44),
#  (16, 27),
#  (24, 40),
#  (36, 5),
#  (47, 5),
#  (16, 36),
#  (17, 1),
#  (35, 49),
#  (13, 49),
#  (36, 14),
#  (47, 14),
#  (28, 10),
#  (36, 23),
#  (9, 6),
#  (17, 19),
#  (28, 19),
#  (36, 32),
#  (28, 28),
#  (17, 28),
#  (48, 6),
#  (5, 35),
#  (6, 0),
#  (29, 2),
#  (17, 37),
#  (28, 37),
#  (6, 9),
#  (40, 11),
#  (42, 39),
#  (21, 16),
#  (30, 46),
#  (39, 24),
#  (39, 33),
#  (12, 25),
#  (23, 25),
#  (12, 34),
#  (31, 47),
#  (43, 12),
#  (4, 30),
#  (12, 43),
#  (2, 11),
#  (20, 47),
#  (35, 8),
#  (23, 43),
#  (35, 17),
#  (4, 48),
#  (43, 30),
#  (24, 26),
#  (35, 26),
#  (16, 22),
#  (24, 35),
#  (24, 44),
#  (13, 44),
#  (36, 9),
#  (16, 40),
#  (17, 5),
#  (46, 41),
#  (36, 18),
#  (16, 49),
#  (17, 14),
#  (9, 10),
#  (49, 46),
#  (5, 39),
#  (6, 4),
#  (29, 6),
#  (6, 13),
#  (8, 41),
#  (19, 41),
#  (39, 19),
#  (31, 15),
#  (20, 15),
#  (39, 28),
#  (11, 46),
#  (31, 24),
#  (20, 24),
#  (12, 20),
#  (20, 33),
#  (31, 33),
#  (23, 29),
#  (31, 42),
#  (43, 7),
#  (23, 38),
#  (24, 3),
#  (35, 3),
#  (32, 16),
#  (4, 34),
#  (23, 47),
#  (1, 10),
#  (24, 12),
#  (32, 25),
#  (16, 8),
#  (24, 21),
#  (1, 19),
#  (43, 34),
#  (13, 21),
#  (24, 30),
#  (16, 26),
#  (36, 4),
#  (16, 35),
#  (17, 0),
#  (46, 36),
#  (38, 32),
#  (5, 7),
#  (46, 45),
#  (9, 14),
#  (26, 48),
#  (30, 27),
#  (42, 29),
#  (27, 40),
#  (0, 32),
#  (19, 45),
#  (20, 10),
#  (31, 10),
#  (11, 41),
#  (12, 6),
#  (39, 23),
#  (20, 19),
#  (31, 19),
#  (31, 28),
#  (4, 11),
#  (20, 28),
#  (23, 24),
#  (4, 20),
#  (32, 2),
#  (32, 11),
#  (23, 42),
#  (12, 42),
#  (13, 7),
#  (43, 20),
#  (4, 38),
#  (32, 20),
#  (24, 16),
#  (1, 5),
#  (13, 16),
#  (24, 7),
#  (4, 47),
#  (1, 23),
#  (37, 44),
#  (35, 25),
#  (46, 22),
#  (49, 27),
#  (17, 4),
#  (5, 2),
#  (28, 4),
#  (15, 34),
#  (9, 0),
#  (5, 11),
#  (46, 49),
#  (26, 43),
#  (15, 43),
#  (9, 9),
#  (7, 39),
#  (42, 6),
#  (27, 17),
#  (18, 48),
#  (42, 15),
#  (30, 22),
#  (42, 24),
#  (11, 18),
#  (8, 31),
#  (19, 31),
#  (42, 33),
#  (19, 40),
#  (20, 5),
#  (0, 36),
#  (23, 1),
#  (19, 49),
#  (20, 14),
#  (8, 49),
#  (11, 45),
#  (23, 10),
#  (31, 23),
#  (23, 19),
#  (31, 32),
#  (20, 32),
#  (23, 28),
#  (12, 37),
#  (45, 34),
#  (13, 11),
#  (16, 7),
#  (22, 41),
#  (37, 39),
#  (46, 17),
#  (14, 46),
#  (38, 13),
#  (49, 13),
#  (46, 26),
#  (49, 22),
#  (38, 31),
#  (15, 29),
#  (5, 6),
#  (49, 40),
#  (27, 3),
#  (15, 38),
#  (18, 34),
#  (42, 1),
#  (38, 49),
#  (27, 12),
#  (26, 47),
#  (7, 43),
#  (8, 8),
#  (42, 10),
#  (27, 21),
#  (27, 30),
#  (42, 28),
#  (27, 39),
#  (0, 22),
#  (8, 35),
#  (30, 35),
#  (11, 31),
#  (39, 13),
#  (8, 44),
#  (30, 44),
#  (0, 31),
#  (41, 41),
#  (31, 18),
#  (4, 1),
#  (23, 14),
#  (44, 46),
#  (4, 10),
#  (23, 23),
#  (32, 1),
#  (4, 19),
#  (43, 1),
#  (22, 36),
#  (45, 38),
#  (34, 38),
#  (37, 34),
#  (45, 47),
#  (46, 12),
#  (3, 41),
#  (14, 41),
#  (49, 8),
#  (46, 21),
#  (38, 17),
#  (15, 15),
#  (26, 24),
#  (18, 20),
#  (15, 33),
#  (49, 35),
#  (18, 29),
#  (15, 42),
#  (27, 7),
#  (18, 38),
#  (7, 38),
#  (27, 16),
#  (18, 47),
#  (8, 12),
#  (27, 25),
#  (11, 8),
#  (30, 21),
#  (42, 23),
#  (8, 30),
#  (19, 30),
#  (39, 8),
#  (20, 4),
#  (41, 36),
#  (31, 13),
#  (33, 32),
#  (44, 32),
#  (23, 9),
#  (10, 48),
#  (34, 15),
#  (4, 14),
#  (25, 46),
#  (2, 44),
#  (22, 22),
#  (22, 31),
#  (34, 33),
#  (14, 27),
#  (37, 29),
#  (22, 40),
#  (3, 36),
#  (22, 49),
#  (46, 16),
#  (26, 10),
#  (38, 12),
#  (49, 12),
#  (7, 6),
#  (7, 15),
#  (18, 15),
#  (38, 30),
#  (15, 28),
#  (49, 30),
#  (15, 37),
#  (27, 2),
#  (7, 33),
#  (42, 0),
#  (18, 42),
#  (8, 7),
#  (30, 7),
#  (27, 20),
#  (0, 3),
#  (11, 3),
#  (42, 9),
#  (11, 12),
#  (0, 12),
#  (19, 25),
#  (29, 48),
#  (0, 21),
#  (33, 27),
#  (44, 27),
#  (41, 40),
#  (23, 4),
#  (4, 0),
#  (10, 34),
#  (45, 10),
#  (34, 10),
#  (34, 19),
#  (45, 28),
#  (37, 24),
#  (34, 37),
#  (46, 2),
#  (22, 44),
#  (14, 40),
#  (49, 7),
#  (46, 20),
#  (18, 1),
#  (3, 49),
#  (14, 49),
#  (15, 14),
#  (49, 16),
#  (7, 10),
#  (18, 10),
#  (26, 23),
#  (18, 19),
#  (7, 28),
#  (48, 29),
#  (18, 28),
#  (18, 37),
#  (29, 34),
#  (40, 34),
#  (30, 11),
#  (48, 47),
#  (11, 7),
#  (6, 41),
#  (40, 43),
#  (21, 39),
#  (44, 13),
#  (33, 13),
#  (41, 26),
#  (10, 20),
#  (44, 31),
#  (41, 44),
#  (33, 40),
#  (34, 5),
#  (25, 36),
#  (37, 1),
#  (44, 49),
#  (2, 43),
#  (22, 21),
#  (34, 23),
#  (45, 23),
#  (14, 17),
#  (37, 19),
#  (45, 32),
#  (37, 28),
#  (3, 26),
#  (46, 6),
#  (15, 0),
#  (26, 0),
#  (3, 44),
#  (49, 11),
#  (18, 5),
#  (26, 18),
#  (7, 14),
#  (48, 15),
#  (48, 24),
#  (29, 20),
#  (40, 20),
#  (48, 33),
#  (6, 27),
#  (21, 25),
#  (11, 2),
#  (40, 38),
#  (6, 36),
#  (21, 34),
#  (40, 47),
#  (6, 45),
#  (29, 47),
#  (44, 8),
#  (41, 21),
#  (25, 4),
#  (33, 17),
#  (44, 17),
#  (25, 13),
#  (33, 26),
#  (41, 39),
#  (25, 22),
#  (44, 35),
#  (10, 33),
#  (34, 0),
#  (44, 44),
#  (25, 40),
#  (22, 16),
#  (45, 18),
#  (37, 14),
#  (37, 23),
#  (14, 21),
#  (36, 27),
#  (18, 0),
#  (47, 36),
#  (15, 13),
#  (26, 13),
#  (18, 9),
#  (48, 10),
#  (17, 41),
#  (9, 37),
#  (6, 22),
#  (6, 31),
#  (6, 40),
#  (21, 38),
#  (10, 1),
#  (6, 49),
#  (33, 3),
#  (41, 16),
#  (10, 10),
#  (44, 12),
#  (41, 25),
#  (2, 6),
#  (10, 19),
#  (44, 21),
#  (33, 21),
#  (2, 15),
#  (25, 17),
#  (33, 30),
#  (34, 4),
#  (37, 0),
#  (22, 11),
#  (43, 43),
#  (14, 7),
#  (32, 43),
#  (24, 39),
#  (13, 39),
#  (3, 16),
#  (35, 39),
#  (35, 48),
#  (3, 25),
#  (36, 22),
#  (17, 18),
#  (36, 31),
#  (18, 4),
#  (48, 5),
#  (28, 36),
#  (29, 1),
#  (47, 49),
#  (9, 32),
#  (48, 14),
#  (28, 45),
#  (29, 10),
#  (6, 8),
#  (9, 41),
#  (29, 19),
#  (40, 19),
#  (48, 32),
#  (21, 15),
#  (40, 28),
#  (21, 24),
#  (40, 37),
#  (41, 2),
#  (41, 11),
#  (33, 7),
#  (41, 20),
#  (25, 3),
#  (10, 14),
#  (33, 16),
#  (2, 10),
#  (2, 19),
#  (32, 29),
#  (43, 29),
#  (2, 37),
#  (3, 2),
#  (32, 38),
#  (13, 34),
#  (35, 34),
#  (36, 17),
#  (28, 13),
#  (17, 13),
#  (47, 26),
#  (36, 26),
#  (47, 35),
#  (9, 18),
#  (5, 29),
#  (47, 44),
#  (9, 27),
#  (5, 38),
#  (29, 5),
#  (17, 40),
#  (40, 5),
#  (48, 18),
#  (29, 14),
#  (48, 27),
#  (40, 23),
#  (40, 32),
#  (21, 28),
#  (44, 2),
#  (33, 2),
#  (39, 45),
#  (31, 41),
#  (25, 16),
#  (12, 46),
#  (23, 46),
#  (2, 23),
#  (22, 1),
#  (35, 29),
#  (14, 6),
#  (43, 42),
#  (32, 42),
#  (1, 36),
#  (13, 38),
#  (16, 34),
#  (13, 47),
#  (36, 12),
#  (47, 12),
#  (24, 47),
#  (17, 8),
#  (36, 21),
#  (9, 4),
#  (17, 17),
#  (28, 17),
#  (17, 26),
#  (36, 39),
#  (28, 35),
#  (48, 13),
#  (9, 31),
#  (5, 42),
#  (9, 40),
#  (6, 16),
#  (21, 14),
#  (0, 49),
#  (2, 0),
#  (20, 36),
#  (25, 2),
#  (32, 10),
#  (12, 41),
#  (32, 19),
#  (24, 15),
#  (43, 37),
#  (24, 33),
#  (32, 46),
#  (36, 7),
#  (47, 7),
#  (16, 38),
#  (1, 49),
#  (5, 10),
#  (36, 25),
#  (9, 8),
#  (17, 30),
#  (9, 26),
#  (48, 8),
#  (40, 4),
#  (6, 2),
#  (9, 35),
#  (21, 0),
#  (27, 34),
#  (40, 13),
#  (21, 9),
#  (39, 17),
#  (31, 22),
#  (39, 35),
#  (31, 31),
#  (23, 27),
#  (20, 40),
#  (20, 49),
#  (32, 14),
#  (32, 23),
#  (16, 6),
#  (35, 19),
#  (43, 32),
#  (32, 32),
#  (13, 28),
#  (16, 24),
#  (1, 35),
#  (46, 34),
#  (36, 11),
#  (47, 11),
#  (28, 7),
#  (9, 3),
#  (49, 39),
#  (28, 16),
#  (9, 12),
#  (9, 21),
#  (5, 32),
#  (42, 18),
#  (27, 29),
#  (21, 4),
#  (30, 34),
#  (19, 34),
#  (42, 36),
#  (39, 12),
#  (42, 45),
#  (20, 8),
#  (20, 17),
#  (31, 17),
#  (39, 30),
#  (12, 13),
#  (20, 26),
#  (39, 39),
#  (20, 35),
#  (32, 0),
#  (23, 31),
#  (31, 44),
#  (4, 27),
#  (13, 5),
#  (32, 18),
#  (4, 36),
#  (12, 49),
#  (24, 14),
#  (13, 14),
#  (13, 23),
#  (1, 21),
#  (35, 23),
#  (16, 28),
#  (38, 25),
#  (46, 38),
#  (49, 34),
#  (5, 9),
#  (17, 11),
#  (28, 11),
#  (26, 41),
#  (9, 7),
#  (5, 18),
#  (46, 47),
#  (9, 16),
#  (42, 22),
#  (42, 31),
#  (27, 42),
#  (8, 38),
#  (30, 38),
#  (0, 34),
#  (11, 34),
#  (31, 12),
#  (0, 43),
#  (12, 8),
#  (39, 25),
#  (4, 4),
#  (12, 17),
#  (20, 30),
#  (4, 13),
#  (15, 12),
#  (23, 35),
#  (35, 0),
#  (24, 0),
#  (4, 31),
#  (32, 13),
#  (43, 13),
#  (24, 9),
#  (35, 9),
#  (1, 7),
#  (34, 41),
#  (13, 18),
#  (37, 37),
#  (24, 18),
#  (16, 14),
#  (1, 25),
#  (16, 23),
#  (46, 24),
#  (15, 27),
#  (38, 29),
#  (49, 29),
#  (38, 38),
#  (26, 36),
#  (5, 13),
#  (18, 32),
#  (38, 47),
#  (7, 41),
#  (18, 41),
#  (8, 15),
#  (30, 15),
#  (11, 11),
#  (0, 11),
#  (30, 24),
#  (42, 26),
#  (27, 37),
#  (11, 20),
#  (30, 33),
#  (42, 35),
#  (27, 46),
#  (39, 11),
#  (11, 29),
#  (8, 42),
#  (30, 42),
#  (19, 42),
#  (0, 38),
#  (12, 3),
#  (23, 3),
#  (39, 20),
#  (20, 7),
#  (20, 16),
#  (41, 48),
#  (42, 7),
#  (12, 21),
#  (12, 30),
#  (25, 49),
#  (45, 27),
#  (34, 27),
#  (1, 2),
#  (13, 4),
#  (24, 4),
#  (16, 0),
#  (34, 36),
#  (22, 34),
#  (45, 36),
#  (46, 1),
#  (16, 9),
#  (45, 45),
#  (1, 20),
#  (37, 41),
#  (46, 10),
#  (35, 13),
#  (46, 19),
#  (37, 32),
#  (14, 48),
#  (38, 15),
#  (15, 22),
#  (38, 24),
#  (46, 37),
#  (38, 33),
#  (49, 33),
#  (18, 27),
#  (37, 49),
#  (49, 42),
#  (7, 27),
#  (30, 1),
#  (15, 49),
#  (27, 14),
#  (7, 45),
#  (19, 10),
#  (19, 19),
#  (27, 32),
#  (11, 15),
#  (8, 28),
#  (30, 28),
#  (11, 24),
#  (39, 6),
#  (30, 37),
#  (31, 2),
#  (39, 15),
#  (20, 11),
#  (12, 7),
#  (31, 20),
#  (33, 39),
#  (12, 16),
#  (23, 16),
#  (4, 12),
#  (34, 13),
#  (25, 44),
#  (45, 22),
#  (37, 18),
#  (1, 6),
#  (34, 40),
#  (49, 1),
#  (46, 14),
#  (15, 8),
#  (38, 10),
#  (49, 10),
#  (26, 17),
#  (49, 19),
#  (18, 13),
#  (7, 13),
#  (15, 26),
#  (18, 22),
#  (7, 31),
#  (26, 44),
#  (27, 9),
#  (8, 5),
#  (48, 41),
#  (27, 18),
#  (11, 1),
#  (7, 49),
#  (42, 16),
#  (19, 14),
#  (18, 49),
#  (0, 10),
#  (11, 10),
#  (29, 46),
#  (0, 19),
#  (39, 1),
#  (11, 19),
#  (11, 28),
#  (41, 29),
#  (44, 34),
#  (44, 43),
#  (45, 8),
#  (34, 17),
#  ...}

# %%
len(_)
# Out:
# 1015

# %%
test_answer = """##....#....#
.#.#....0...
..#.#0....#.
..##...0....
....0....#..
.#...#A....#
...#..#.....
#....#.#....
..#.....A...
....#....A..
.#........#.
...#......##"""

# %%
for i,l in enumerate(test_answer.splitlines()):
  print(l)
  for j,c in enumerate(l):
    if c in '#A0':
      print(  (i,j))
# Out:
# ##....#....#
# (0, 0)
# (0, 1)
# (0, 6)
# (0, 11)
# .#.#....0...
# (1, 1)
# (1, 3)
# (1, 8)
# ..#.#0....#.
# (2, 2)
# (2, 4)
# (2, 5)
# (2, 10)
# ..##...0....
# (3, 2)
# (3, 3)
# (3, 7)
# ....0....#..
# (4, 4)
# (4, 9)
# .#...#A....#
# (5, 1)
# (5, 5)
# (5, 6)
# (5, 11)
# ...#..#.....
# (6, 3)
# (6, 6)
# #....#.#....
# (7, 0)
# (7, 5)
# (7, 7)
# ..#.....A...
# (8, 2)
# (8, 8)
# ....#....A..
# (9, 4)
# (9, 9)
# .#........#.
# (10, 1)
# (10, 10)
# ...#......##
# (11, 3)
# (11, 10)
# (11, 11)

# %%
simple="""T.........
...T......
.T........
..........
..........
..........
..........
..........
..........
..........""".splitlines()

# %%
g = Grid(simple)
g.find_antinodes()
# Out:
# harmonizing from (0, 1), delta: (1, 3), dir: 1
# adding (0, 1)
# adding (1, 4)
# adding (2, 7)
# harmonizing from (0, 1), delta: (1, 3), dir: -1
# adding (0, 1)
# harmonizing from (0, 2), delta: (2, 1), dir: 1
# adding (0, 2)
# adding (2, 3)
# adding (4, 4)
# adding (6, 5)
# adding (8, 6)
# harmonizing from (0, 2), delta: (2, 1), dir: -1
# adding (0, 2)
# harmonizing from (1, 2), delta: (1, -2), dir: 1
# adding (1, 2)
# adding (2, 0)
# harmonizing from (1, 2), delta: (1, -2), dir: -1
# adding (1, 2)
# adding (0, 4)
# {(0, 1),
#  (0, 2),
#  (0, 4),
#  (1, 2),
#  (1, 4),
#  (2, 0),
#  (2, 3),
#  (2, 7),
#  (4, 4),
#  (6, 5),
#  (8, 6)}

# %%
print("""T....#....
...T......
.T....#...
.........#
..#.......
..........
...#......
..........
....#.....
..........""")
# Out:
# T....#....
# ...T......
# .T....#...
# .........#
# ..#.......
# ..........
# ...#......
# ..........
# ....#.....
# ..........

# %%
g.antinodes
# Out:
# {(0, 1),
#  (0, 2),
#  (0, 4),
#  (1, 2),
#  (1, 4),
#  (2, 0),
#  (2, 3),
#  (2, 7),
#  (4, 4),
#  (6, 5),
#  (8, 6)}

# %%
456567238446228 - 456565678667482
# this was the diff between whether it early terminates, and the rule that broke the old code using that 1 example.
# Needed to check that the value matched the goal AND there were no more numbers in the queue.
# Out:
# 1559778746
